# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.
# Licensed under the MIT License.

# %% [markdown]
# ![Impressions](https://PixelServer20190423114238.azurewebsites.net/api/impressions/NotebookVM/how-to-use-azureml/machine-learning-pipelines/intro-to-pipelines/aml-pipelines-with-automated-machine-learning-step.png)

# %% [markdown]
# # Azure Machine Learning Pipeline with AutoMLStep (Udacity Course 2)
# This notebook demonstrates the use of AutoMLStep in Azure Machine Learning Pipeline.

# %% [markdown]
# ## Introduction
# In this example we showcase how you can use AzureML Dataset to load data for AutoML via AML Pipeline.
#
# If you are using an Azure Machine Learning Notebook VM, you are all set. Otherwise, make sure you have executed the [configuration](https://aka.ms/pl-config) before running this notebook.
#
# In this notebook you will learn how to:
# 1. Create an `Experiment` in an existing `Workspace`.
# 2. Create or Attach existing AmlCompute to a workspace.
# 3. Define data loading in a `TabularDataset`.
# 4. Configure AutoML using `AutoMLConfig`.
# 5. Use AutoMLStep
# 6. Train the model using AmlCompute
# 7. Explore the results.
# 8. Test the best fitted model.

# %% [markdown]
# ## Azure Machine Learning and Pipeline SDK-specific imports

# %%
import logging
import os
import csv

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from sklearn import datasets
import pkg_resources

import azureml.core
from azureml.core.experiment import Experiment
from azureml.core.workspace import Workspace
from azureml.train.automl import AutoMLConfig
from azureml.core.dataset import Dataset

from azureml.pipeline.steps import AutoMLStep

# Check core SDK version number
print("SDK version:", azureml.core.VERSION)
# Out:
# SDK version: 1.18.0

# %% [markdown]
# ## Initialize Workspace
# Initialize a workspace object from persisted configuration. Make sure the config file is present at .\config.json

# %%
ws = Workspace.from_config()
print(ws.name, ws.resource_group, ws.location, ws.subscription_id, sep = '\n')
# Out:
# quick-starts-ws-126656
# aml-quickstarts-126656
# southcentralus
# 2248b1c7-a065-4265-9476-038b58f0650e

# %% [markdown]
# ## Create an Azure ML experiment
# Let's create an experiment named "automlstep-classification" and a folder to hold the training scripts. The script runs will be recorded under the experiment in Azure.
#
# The best practice is to use separate folders for scripts and its dependent files for each step and specify that folder as the `source_directory` for the step. This helps reduce the size of the snapshot created for the step (only the specific folder is snapshotted). Since changes in any files in the `source_directory` would trigger a re-upload of the snapshot, this helps keep the reuse of the step when there are no changes in the `source_directory` of the step.
#
# *Udacity Note:* There is no need to create an Azure ML experiment, this needs to re-use the experiment that was already created

# %%
# Choose a name for the run history container in the workspace.
# NOTE: update these to match your existing experiment name
experiment_name = 'ml-experiment-1'
project_folder = './pipeline-project'

experiment = Experiment(ws, experiment_name)
experiment
# Out:
# Experiment(Name: ml-experiment-1,
# Workspace: quick-starts-ws-126656)

# %% [markdown]
# ### Create or Attach an AmlCompute cluster
# You will need to create a [compute target](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#compute-target) for your AutoML run. In this tutorial, you get the default `AmlCompute` as your training compute resource.
#
# **Udacity Note** There is no need to create a new compute target, it can re-use the previous cluster

# %%
from azureml.core.compute import AmlCompute
from azureml.core.compute import ComputeTarget
from azureml.core.compute_target import ComputeTargetException

# NOTE: update the cluster name to match the existing cluster
# Choose a name for your CPU cluster
amlcompute_cluster_name = "nuria-aml"

# Verify that cluster does not exist already
try:
    compute_target = ComputeTarget(workspace=ws, name=amlcompute_cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_D2_V2',# for GPU, use "STANDARD_NC6"
                                                           #vm_priority = 'lowpriority', # optional
                                                           max_nodes=4)
    compute_target = ComputeTarget.create(ws, amlcompute_cluster_name, compute_config)

    compute_target.wait_for_completion(show_output=True, min_node_count = 1, timeout_in_minutes = 10)
# For a more detailed view of current AmlCompute status, use get_status().
# Out:
# Found existing cluster, use it.

# %% [markdown]
# ## Data
#
# **Udacity note:** Make sure the `key` is the same name as the dataset that is uploaded, and that the description matches. If it is hard to find or unknown, loop over the `ws.datasets.keys()` and `print()` them.
# If it *isn't* found because it was deleted, it can be recreated with the link that has the CSV

# %%
# Try to load the dataset from the Workspace. Otherwise, create it from the file
# NOTE: update the key to match the dataset name
found = False
key = "BankMarketing Dataset"
description_text = "Bank Marketing DataSet for Udacity Course 2"

if key in ws.datasets.keys(): 
        found = True
        dataset = ws.datasets[key] 

if not found:
        # Create AML Dataset and register it into Workspace
        example_data = 'https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv'
        dataset = Dataset.Tabular.from_delimited_files(example_data)        
        #Register Dataset in Workspace
        dataset = dataset.register(workspace=ws,
                                   name=key,
                                   description=description_text)


df = dataset.to_pandas_dataframe()
df.describe()
# Out:
#                 age      duration      campaign         pdays      previous  \
# count  32950.000000  32950.000000  32950.000000  32950.000000  32950.000000
# mean      40.040212    257.335205      2.561730    962.174780      0.174780
# std       10.432313    257.331700      2.763646    187.646785      0.496503
# min       17.000000      0.000000      1.000000      0.000000      0.000000
# 25%       32.000000    102.000000      1.000000    999.000000      0.000000
# 50%       38.000000    179.000000      2.000000    999.000000      0.000000
# 75%       47.000000    318.000000      3.000000    999.000000      0.000000
# max       98.000000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  32950.000000    32950.000000   32950.000000  32950.000000  32950.000000
# mean       0.076228       93.574243     -40.518680      3.615654   5166.859608
# std        1.572242        0.578636       4.623004      1.735748     72.208448
# min       -3.400000       92.201000     -50.800000      0.634000   4963.600000
# 25%       -1.800000       93.075000     -42.700000      1.344000   5099.100000
# 50%        1.100000       93.749000     -41.800000      4.857000   5191.000000
# 75%        1.400000       93.994000     -36.400000      4.961000   5228.100000
# max        1.400000       94.767000     -26.900000      5.045000   5228.100000

# %% [markdown]
# ### Review the Dataset Result
#
# You can peek the result of a TabularDataset at any range using `skip(i)` and `take(j).to_pandas_dataframe()`. Doing so evaluates only `j` records for all the steps in the TabularDataset, which makes it fast even against large datasets.
#
# `TabularDataset` objects are composed of a list of transformation steps (optional).

# %%
dataset.take(5).to_pandas_dataframe()
# Out:
#    age          job  marital    education  default housing loan    contact  \
# 0   57   technician  married  high.school       no      no  yes   cellular
# 1   55      unknown  married      unknown  unknown     yes   no  telephone
# 2   33  blue-collar  married     basic.9y       no      no   no   cellular
# 3   36       admin.  married  high.school       no      no   no  telephone
# 4   27    housemaid  married  high.school       no     yes   no   cellular
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         1      failure         -1.8
# 1   may         thu  ...         2    999         0  nonexistent          1.1
# 2   may         fri  ...         1    999         1      failure         -1.8
# 3   jun         fri  ...         4    999         0  nonexistent          1.4
# 4   jul         fri  ...         2    999         0  nonexistent          1.4
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          92.893          -46.2      1.299       5099.1  no
# 1          93.994          -36.4      4.860       5191.0  no
# 2          92.893          -46.2      1.313       5099.1  no
# 3          94.465          -41.8      4.967       5228.1  no
# 4          93.918          -42.7      4.963       5228.1  no
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Train
# This creates a general AutoML settings object.
# **Udacity notes:** These inputs must match what was used when training in the portal. `label_column_name` has to be `y` for example.

# %%
automl_settings = {
    "experiment_timeout_minutes": 20,
    "max_concurrent_iterations": 5,
    "primary_metric" : 'AUC_weighted'
}
automl_config = AutoMLConfig(compute_target=compute_target,
                             task = "classification",
                             training_data=dataset,
                             label_column_name="y",   
                             path = project_folder,
                             enable_early_stopping= True,
                             featurization= 'auto',
                             debug_log = "automl_errors.log",
                             **automl_settings
                            )

# %% [markdown]
# #### Create Pipeline and AutoMLStep
#
# You can define outputs for the AutoMLStep using TrainingOutput.

# %%
from azureml.pipeline.core import PipelineData, TrainingOutput

ds = ws.get_default_datastore()
metrics_output_name = 'metrics_output'
best_model_output_name = 'best_model_output'

metrics_data = PipelineData(name='metrics_data',
                           datastore=ds,
                           pipeline_output_name=metrics_output_name,
                           training_output=TrainingOutput(type='Metrics'))
model_data = PipelineData(name='model_data',
                           datastore=ds,
                           pipeline_output_name=best_model_output_name,
                           training_output=TrainingOutput(type='Model'))

# %% [markdown]
# Create an AutoMLStep.

# %%
automl_step = AutoMLStep(
    name='automl_module',
    automl_config=automl_config,
    outputs=[metrics_data, model_data],
    allow_reuse=True)

# %%
from azureml.pipeline.core import Pipeline
pipeline = Pipeline(
    description="pipeline_with_automlstep",
    workspace=ws,    
    steps=[automl_step])

# %%
pipeline_run = experiment.submit(pipeline)
# Out:
# Created step automl_module [c9bee589][c766de30-3188-4822-83e0-0da9472c3a7c], (This step will run and generate new outputs)
# Submitted PipelineRun f9b55692-92b6-4d4e-809b-42b7813fbe5a
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/ml-experiment-1/runs/f9b55692-92b6-4d4e-809b-42b7813fbe5a?wsid=/subscriptions/2248b1c7-a065-4265-9476-038b58f0650e/resourcegroups/aml-quickstarts-126656/workspaces/quick-starts-ws-126656

# %%
from azureml.widgets import RunDetails
RunDetails(pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …

# %%
pipeline_run.wait_for_completion()
# Out:
# PipelineRunId: f9b55692-92b6-4d4e-809b-42b7813fbe5a
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/ml-experiment-1/runs/f9b55692-92b6-4d4e-809b-42b7813fbe5a?wsid=/subscriptions/2248b1c7-a065-4265-9476-038b58f0650e/resourcegroups/aml-quickstarts-126656/workspaces/quick-starts-ws-126656
# PipelineRun Status: Running
#
#
# StepRunId: d1860d72-7c14-419f-be9b-32d90bb2b64d
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/ml-experiment-1/runs/d1860d72-7c14-419f-be9b-32d90bb2b64d?wsid=/subscriptions/2248b1c7-a065-4265-9476-038b58f0650e/resourcegroups/aml-quickstarts-126656/workspaces/quick-starts-ws-126656
# StepRun( automl_module ) Status: Running
#
# StepRun(automl_module) Execution Summary
# =========================================
# StepRun( automl_module ) Status: Finished
# {'runId': 'd1860d72-7c14-419f-be9b-32d90bb2b64d', 'target': 'nuria-aml', 'status': 'Completed', 'startTimeUtc': '2020-11-17T18:31:52.406077Z', 'endTimeUtc': '2020-11-17T19:06:13.045105Z', 'properties': {'azureml.runsource': 'azureml.StepRun', 'ContentSnapshotId': '7c547866-17dc-474f-a6f5-fde59f911916', 'StepType': 'AutoMLStep', 'azureml.moduleid': 'c766de30-3188-4822-83e0-0da9472c3a7c', 'azureml.nodeid': 'c9bee589', 'azureml.pipelinerunid': 'f9b55692-92b6-4d4e-809b-42b7813fbe5a', 'num_iterations': '1000', 'training_type': 'TrainFull', 'acquisition_function': 'EI', 'metrics': 'accuracy', 'primary_metric': 'AUC_weighted', 'train_split': '0', 'MaxTimeSeconds': None, 'acquisition_parameter': '0', 'num_cross_validation': None, 'target': 'nuria-aml', 'RawAMLSettingsString': None, 'AMLSettingsJsonString': '{"path": null, "name": "placeholder", "subscription_id": "2248b1c7-a065-4265-9476-038b58f0650e", "resource_group": "aml-quickstarts-126656", "workspace_name": "quick-starts-ws-126656", "region": "southcentralus", "compute_target": "nuria-aml", "spark_service": null, "azure_service": null, "_local_managed_run_id": null, "many_models": false, "pipeline_fetch_max_batch_size": 1, "iterations": 1000, "primary_metric": "AUC_weighted", "task_type": "classification", "data_script": null, "validation_size": 0.0, "n_cross_validations": null, "y_min": null, "y_max": null, "num_classes": null, "featurization": "auto", "_ignore_package_version_incompatibilities": false, "is_timeseries": false, "max_cores_per_iteration": 1, "max_concurrent_iterations": 5, "iteration_timeout_minutes": null, "mem_in_mb": null, "enforce_time_on_windows": false, "experiment_timeout_minutes": 20, "experiment_exit_score": null, "whitelist_models": null, "blacklist_algos": null, "supported_models": ["SGD", "TensorFlowLinearClassifier", "RandomForest", "SVM", "TensorFlowDNN", "LightGBM", "AveragedPerceptronClassifier", "DecisionTree", "XGBoostClassifier", "MultinomialNaiveBayes", "GradientBoosting", "LogisticRegression", "ExtremeRandomTrees", "BernoulliNaiveBayes", "LinearSVM", "KNN"], "auto_blacklist": true, "blacklist_samples_reached": false, "exclude_nan_labels": true, "verbosity": 20, "_debug_log": "automl_errors.log", "show_warnings": false, "model_explainability": true, "service_url": null, "sdk_url": null, "sdk_packages": null, "enable_onnx_compatible_models": false, "enable_split_onnx_featurizer_estimator_models": false, "vm_type": "STANDARD_D2_V2", "telemetry_verbosity": 20, "send_telemetry": true, "enable_dnn": false, "scenario": "SDK-1.13.0", "environment_label": null, "force_text_dnn": false, "enable_feature_sweeping": true, "enable_early_stopping": true, "early_stopping_n_iters": 10, "metrics": null, "enable_ensembling": true, "enable_stack_ensembling": true, "ensemble_iterations": 15, "enable_tf": false, "enable_subsampling": null, "subsample_seed": null, "enable_nimbusml": false, "enable_streaming": false, "force_streaming": false, "track_child_runs": true, "allowed_private_models": [], "label_column_name": "y", "weight_column_name": null, "cv_split_column_names": null, "enable_local_managed": false, "cost_mode": 1, "lag_length": 0, "metric_operation": "maximize", "preprocess": true}', 'DataPrepJsonString': '{\\"training_data\\": {\\"datasetId\\": \\"477a8be5-56ae-49de-877e-f5bde80f5f17\\"}, \\"datasets\\": 0}', 'EnableSubsampling': 'False', 'runTemplate': 'AutoML', 'Orchestrator': 'automl', 'ClientType': 'Others', '_aml_system_scenario_identification': 'Remote.Parent', 'root_attribution': 'azureml.StepRun', 'snapshotId': '7c547866-17dc-474f-a6f5-fde59f911916', 'SetupRunId': 'd1860d72-7c14-419f-be9b-32d90bb2b64d_setup', 'SetupRunContainerId': 'dcid.d1860d72-7c14-419f-be9b-32d90bb2b64d_setup', 'ClientSdkVersion': '1.18.0', 'FeaturizationRunJsonPath': 'featurizer_container.json', 'FeaturizationRunId': 'd1860d72-7c14-419f-be9b-32d90bb2b64d_featurize', 'ProblemInfoJsonString': '{"dataset_num_categorical": 0, "is_sparse": true, "subsampling": false, "dataset_c ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': 'f9b55692-92b6-4d4e-809b-42b7813fbe5a', 'status': 'Completed', 'startTimeUtc': '2020-11-17T18:31:10.180524Z', 'endTimeUtc': '2020-11-17T19:08:50.937925Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://mlstrg126656.blob.core.windows.net/azureml/ExperimentRun/dcid.f9b55692-92b6-4d4e-809b-42b7813fbe5a/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=62fqfOqEDb7Blav6haBarZtVbrLEGp6MLi7jOAuB2xQ%3D&st=2020-11-17T18%3A21%3A43Z&se=2020-11-18T02%3A31%3A43Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://mlstrg126656.blob.core.windows.net/azureml/ExperimentRun/dcid.f9b55692-92b6-4d4e-809b-42b7813fbe5a/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=%2BOAoT2KS1ZCm6Vkf7t6at3eZZtyLncIBPWZTNg77w7s%3D&st=2020-11-17T18%3A21%3A43Z&se=2020-11-18T02%3A31%3A43Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://mlstrg126656.blob.core.windows.net/azureml/ExperimentRun/dcid.f9b55692-92b6-4d4e-809b-42b7813fbe5a/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=wKj0Zrcp%2FPe75VzTTaGECgm6mOeoIYjgxxxAvmcEjY0%3D&st=2020-11-17T18%3A21%3A43Z&se=2020-11-18T02%3A31%3A43Z&sp=r'}}
# 'Finished'

# %% [markdown]
# ## Examine Results
#
# ### Retrieve the metrics of all child runs
# Outputs of above run can be used as inputs of other steps in pipeline. In this tutorial, we will examine the outputs by retrieve output data and running some tests.

# %%
metrics_output = pipeline_run.get_pipeline_output(metrics_output_name)
num_file_downloaded = metrics_output.download('.', show_progress=True)
# Out:
# Downloading azureml/d1860d72-7c14-419f-be9b-32d90bb2b64d/metrics_data
# Downloaded azureml/d1860d72-7c14-419f-be9b-32d90bb2b64d/metrics_data, 1 files out of an estimated total of 1

# %%
import json
with open(metrics_output._path_on_datastore) as f:
    metrics_output_result = f.read()
    
deserialized_metrics_output = json.loads(metrics_output_result)
df = pd.DataFrame(deserialized_metrics_output)
df
# Out:
#                                  d1860d72-7c14-419f-be9b-32d90bb2b64d_15  \
# balanced_accuracy                                   [0.5558732381582189]
# f1_score_weighted                                   [0.8616381668658735]
# norm_macro_recall                                  [0.11174647631643775]
# f1_score_macro                                      [0.5733594733009783]
# matthews_correlation                                 [0.270276528071055]
# weighted_accuracy                                   [0.9814595619476877]
# average_precision_score_macro                       [0.7653470707895635]
# precision_score_micro                               [0.8968133535660091]
# precision_score_weighted                            [0.8830896521268605]
# average_precision_score_micro                       [0.9726986744232002]
# log_loss                                           [0.21892824818362216]
# average_precision_score_weighted                    [0.9390150395217173]
# AUC_macro                                           [0.9172612795847712]
# AUC_weighted                                        [0.9172612795847712]
# f1_score_micro                                      [0.8968133535660091]
# accuracy                                            [0.8968133535660091]
# recall_score_micro                                  [0.8968133535660091]
# AUC_micro                                           [0.9713045700825041]
# precision_score_macro                               [0.8268532665821441]
# recall_score_macro                                  [0.5558732381582189]
# recall_score_weighted                               [0.8968133535660091]
#
#                                  d1860d72-7c14-419f-be9b-32d90bb2b64d_23  \
# balanced_accuracy                                   [0.5873562324139987]
# f1_score_weighted                                   [0.8730666405599883]
# norm_macro_recall                                   [0.1747124648279974]
# f1_score_macro                                       [0.619379416282642]
# matthews_correlation                               [0.32759065030497087]
# weighted_accuracy                                   [0.9778104098848917]
# average_precision_score_macro                       [0.7367680211556877]
# precision_score_micro                               [0.9001517450682853]
# precision_score_weighted                            [0.8837821213097226]
# average_precision_score_micro                       [0.9679027096531867]
# log_loss                                            [0.2489499592871082]
# average_precision_score_weighted                    [0.9296558619259861]
# AUC_macro                                           [0.8927696180584499]
# AUC_weighted                                        [0.8927696180584499]
# f1_score_micro                                      [0.9001517450682853]
# accuracy                                            [0.9001517450682853]
# recall_score_micro                                  [0.9001517450682853]
# AUC_micro                                           [0.9665299656213373]
# precision_score_macro                               [0.8071207148067104]
# recall_score_macro                                  [0.5873562324139987]
# recall_score_weighted                               [0.9001517450682853]
#
#                                  d1860d72-7c14-419f-be9b-32d90bb2b64d_10  \
# balanced_accuracy                                                  [0.5]
# f1_score_weighted                                   [0.8353395018439429]
# norm_macro_recall                                                  [0.0]
# f1_score_macro                                      [0.4703423886834914]
# matthews_correlation                                               [0.0]
# weighted_accuracy                                   [0.9843450583187134]
# average_precision_score_macro                       [0.7051662806969468]
# precision_score_micro                               [0.8880121396054628]
# precision_score_weighted                             [0.788565560086672]
# average_precision_score_micro                       [0.9643453945406018]
# log_loss                                           [0.26558076331059494]
# average_precision_score_weighted                    [0.9205139871933353]
# AUC_macro                                           [0.8794695534105034]
# AUC_weighted                                        [0.8794695534105035]
# f1_score_micro                                      [0.8880121396054628]
# accuracy                                            [0.8880121396054628]
# recall_score_micro                                  [0.8880121396054628]
# AUC_micro                                           [0.9634860378418582]
# precision_score_macro                               [0.4440060698027314]
# recall_score_macro                                                 [0.5]
# recall_score_weighted                               [0.8880121396054628]
#
#                                  d1860d72-7c14-419f-be9b-32d90bb2b64d_32  \
# balanced_accuracy                                    [0.724763683043529]
# f1_score_weighted                                   [0.9039219348737966]
# norm_macro_recall                                    [0.449527366087058]
# f1_score_macro                                      [0.7469309675333606]
# matthews_correlation                               [0.49881256847663513]
# weighted_accuracy                                   [0.9543033354921573]
# average_precision_score_macro                        [0.809408807756427]
# precision_score_micro                                [0.908649468892261]
# precision_score_weighted                            [0.9011568762582128]
# average_precision_score_micro                       [0.9793488243667532]
# log_loss                                           [0.18598497314459558]
# average_precision_score_weighted                    [0.9513421484543777]
# AUC_macro                                           [0.9399237191278269]
# AUC_weighted                                        [0.9399237191278269]
# f1_score_micro                                       [0.908649468892261]
# accuracy                                             [0.908649468892261]
# recall_score_micro                                   [0.908649468892261]
# AUC_micro                                           [0.9783186462221465]
# precision_score_macro                               [0.7767506466136603]
# recall_score_macro                                   [0.724763683043529]
# recall_score_weighted                                [0.908649468892261]
#
#                                  d1860d72-7c14-419f-be9b-32d90bb2b64d_34  \
# balanced_accuracy                                   [0.6619806167302957]
# f1_score_weighted                                   [0.8919470742505959]
# norm_macro_recall                                  [0.32396123346059147]
# f1_score_macro                                      [0.6989550549185684]
# matthews_correlation                               [0.42391501704399254]
# weighted_accuracy                                   [0.9645869332095605]
# average_precision_score_macro                        [0.775785469246274]
# precision_score_micro                               [0.9044006069802731]
# precision_score_weighted                             [0.889878489588611]
# average_precision_score_micro                       [0.9742899565343723]
# log_loss                                            [0.2122103094509684]
# average_precision_score_weighted                    [0.9415434482618823]
# AUC_macro                                           [0.9206603908144345]
# AUC_weighted                                        [0.9206603908144345]
# f1_score_micro                                      [0.9044006069802731]
# accuracy                                            [0.9044006069802731]
# recall_score_micro                                  [0.9044006069802731]
# AUC_micro                                           [0.9731539717371931]
# precision_score_macro                               [0.7773540830113993]
# recall_score_macro                                  [0.6619806167302957]
# recall_score_weighted                               [0.9044006069802731]
#
#                                  d1860d72-7c14-419f-be9b-32d90bb2b64d_1  \
# balanced_accuracy                                  [0.7191727470931578]
# f1_score_weighted                                  [0.9021127651963996]
# norm_macro_recall                                 [0.43834549418631563]
# f1_score_macro                                     [0.7416848907681176]
# matthews_correlation                                [0.488678780261868]
# weighted_accuracy                                  [0.9537972210153172]
# average_precision_score_macro                      [0.8065229883244922]
# precision_score_micro                              [0.9071320182094081]
# precision_score_weighted                           [0.8991976076061607]
# average_precision_score_micro                      [0.9791945367231853]
# log_loss                                           [0.1874363495858499]
# average_precision_score_weighted                   [0.9505970434373063]
# AUC_macro                                          [0.9392346349984347]
# AUC_weighted                                       [0.9392346349984347]
# f1_score_micro                                     [0.9071320182094081]
# accuracy                                           [0.9071320182094081]
# recall_score_micro                                 [0.9071320182094081]
# AUC_micro                                          [0.9781770788959222]
# precision_score_macro                              [0.7723958081530135]
# recall_score_macro                                 [0.7191727470931578]
# recall_score_weighted                              [0.9071320182094081]
#
#                                  d1860d72-7c14-419f-be9b-32d90bb2b64d_2  \
# balanced_accuracy                                   [0.568056319660941]
# f1_score_weighted                                  [0.8659116470575816]
# norm_macro_recall                                  [0.1361126393218819]
# f1_score_macro                                     [0.5918718099811494]
# matthews_correlation                               [0.2877996303413399]
# weighted_accuracy                                  [0.9791925094137639]
# average_precision_score_macro                      [0.7477934494676948]
# precision_score_micro                              [0.8974203338391502]
# precision_score_weighted                            [0.880003694662532]
# average_precision_score_micro                      [0.9705216820170737]
# log_loss                                          [0.23904037086245908]
# average_precision_score_weighted                   [0.9338172266904018]
# AUC_macro                                          [0.9062729810483341]
# AUC_weighted                                       [0.9062729810483341]
# f1_score_micro                                     [0.8974203338391502]
# accuracy                                           [0.8974203338391502]
# recall_score_micro                                 [0.8974203338391502]
# AUC_micro                                          [0.9691159410612024]
# precision_score_macro                              [0.8042650103519668]
# recall_score_macro                                  [0.568056319660941]
# recall_score_weighted                              [0.8974203338391502]
#
#                                  d1860d72-7c14-419f-be9b-32d90bb2b64d_14  \
# balanced_accuracy                                                  [0.5]
# f1_score_weighted                                   [0.8353395018439429]
# norm_macro_recall                                                  [0.0]
# f1_score_macro                                      [0.4703423886834914]
# matthews_correlation                                               [0.0]
# weighted_accuracy                                   [0.9843450583187134]
# average_precision_score_macro                       [0.7038646599527278]
# precision_score_micro                               [0.8880121396054628]
# precision_score_weighted                             [0.788565560086672]
# average_precision_score_micro                       [0.9656363894161852]
# log_loss                                           [0.25517958776086364]
# average_precision_score_weighted                    [0.9215716713292498]
# AUC_macro                                           [0.8903193867892198]
# AUC_weighted                                        [0.8903193867892198]
# f1_score_micro                                      [0.8880121396054628]
# accuracy                                            [0.8880121396054628]
# recall_score_micro                                  [0.8880121396054628]
# AUC_micro                                           [0.9656439954775824]
# precision_score_macro                               [0.4440060698027314]
# recall_score_macro                                                 [0.5]
# recall_score_weighted                               [0.8880121396054628]
#
#                                  d1860d72-7c14-419f-be9b-32d90bb2b64d_17  \
# balanced_accuracy                                   [0.6538264545324879]
# f1_score_weighted                                   [0.8863308046376278]
# norm_macro_recall                                   [0.3076529090649758]
# f1_score_macro                                      [0.6857817915270039]
# matthews_correlation                               [0.39199420789729694]
# weighted_accuracy                                   [0.9590346205526857]
# average_precision_score_macro                       [0.7478267341285232]
# precision_score_micro                               [0.8983308042488619]
# precision_score_weighted                            [0.8824480675215448]
# average_precision_score_micro                       [0.9690391932132435]
# log_loss                                           [0.23356638769289334]
# average_precision_score_weighted                     [0.933410498373691]
# AUC_macro                                           [0.9051360848536715]
# AUC_weighted                                        [0.9051360848536715]
# f1_score_micro                                      [0.8983308042488619]
# accuracy                                            [0.8983308042488619]
# recall_score_micro                                  [0.8983308042488619]
# AUC_micro                                           [0.9683031953965289]
# precision_score_macro                               [0.7497285975485066]
# recall_score_macro                                  [0.6538264545324879]
# recall_score_weighted                               [0.8983308042488619]
#
#                                  d1860d72-7c14-419f-be9b-32d90bb2b64d_27  ...  \
# balanced_accuracy                                   [0.6734801712337014]  ...
# f1_score_weighted                                   [0.8933801082349104]  ...
# norm_macro_recall                                   [0.3469603424674028]  ...
# f1_score_macro                                      [0.7071747464623881]  ...
# matthews_correlation                               [0.43288996462614715]  ...
# weighted_accuracy                                   [0.9609742278276272]  ...
# average_precision_score_macro                       [0.7650108288539212]  ...
# precision_score_micro                                [0.903793626707132]  ...
# precision_score_weighted                            [0.8903393545710969]  ...
# average_precision_score_micro                       [0.9685175724643347]  ...
# log_loss                                           [0.22317558127491655]  ...
# average_precision_score_weighted                    [0.9398613471349626]  ...
# AUC_macro                                           [0.9255752092722568]  ...
# AUC_weighted                                        [0.9255752092722569]  ...
# f1_score_micro                                       [0.903793626707132]  ...
# accuracy                                             [0.903793626707132]  ...
# recall_score_micro                                   [0.903793626707132]  ...
# AUC_micro                                           [0.9709293291670602]  ...
# precision_score_macro                               [0.7700506348094129]  ...
# recall_score_macro                                  [0.6734801712337014]  ...
# recall_score_weighted                                [0.903793626707132]  ...
#
#                                  d1860d72-7c14-419f-be9b-32d90bb2b64d_3  \
# balanced_accuracy                                   [0.833840884546918]
# f1_score_weighted                                  [0.8866462209016032]
# norm_macro_recall                                  [0.6676817690938359]
# f1_score_macro                                     [0.7527991838645249]
# matthews_correlation                               [0.5364054466448556]
# weighted_accuracy                                  [0.8828983090464687]
# average_precision_score_macro                      [0.7597066058909636]
# precision_score_micro                              [0.8731411229135053]
# precision_score_weighted                           [0.9130030979602081]
# average_precision_score_micro                      [0.9189406544974978]
# log_loss                                          [0.33378354928022896]
# average_precision_score_weighted                   [0.9378454288881078]
# AUC_macro                                          [0.9191502407163512]
# AUC_weighted                                       [0.9191502407163511]
# f1_score_micro                                     [0.8731411229135054]
# accuracy                                           [0.8731411229135053]
# recall_score_micro                                 [0.8731411229135053]
# AUC_micro                                          [0.9349307936566418]
# precision_score_macro                              [0.7154700161880783]
# recall_score_macro                                  [0.833840884546918]
# recall_score_weighted                              [0.8731411229135053]
#
#                                  d1860d72-7c14-419f-be9b-32d90bb2b64d_22  \
# balanced_accuracy                                   [0.7392302819132087]
# f1_score_weighted                                   [0.7886606936964442]
# norm_macro_recall                                  [0.47846056382641744]
# f1_score_macro                                       [0.615037970458149]
# matthews_correlation                                [0.3271695405487751]
# weighted_accuracy                                   [0.7465177036015644]
# average_precision_score_macro                       [0.7063525662308513]
# precision_score_micro                               [0.7450682852807283]
# precision_score_weighted                            [0.8794289828356799]
# average_precision_score_micro                       [0.7931917859500793]
# log_loss                                            [0.5710150806657411]
# average_precision_score_weighted                    [0.9077981614328915]
# AUC_macro                                            [0.812679796312659]
# AUC_weighted                                        [0.8126797963126589]
# f1_score_micro                                      [0.7450682852807284]
# accuracy                                            [0.7450682852807283]
# recall_score_micro                                  [0.7450682852807283]
# AUC_micro                                           [0.8199165056725946]
# precision_score_macro                                [0.611858652891746]
# recall_score_macro                                  [0.7392302819132087]
# recall_score_weighted                               [0.7450682852807283]
#
#                                  d1860d72-7c14-419f-be9b-32d90bb2b64d_28  \
# balanced_accuracy                                   [0.5607806471092736]
# f1_score_weighted                                    [0.863430281058817]
# norm_macro_recall                                  [0.12156129421854711]
# f1_score_macro                                      [0.5810153935830751]
# matthews_correlation                               [0.27777118603290957]
# weighted_accuracy                                   [0.9806200235765187]
# average_precision_score_macro                       [0.7612266627797737]
# precision_score_micro                               [0.8971168437025797]
# precision_score_weighted                            [0.8817543360178732]
# average_precision_score_micro                       [0.9651578735738072]
# log_loss                                            [0.4834636009232872]
# average_precision_score_weighted                    [0.9326636719309545]
# AUC_macro                                           [0.9006700046494654]
# AUC_weighted                                        [0.9006700046494654]
# f1_score_micro                                      [0.8971168437025797]
# accuracy                                            [0.8971168437025797]
# recall_score_micro                                  [0.8971168437025797]
# AUC_micro                                           [0.9681257987339994]
# precision_score_macro                               [0.8173577259362427]
# recall_score_macro                                  [0.5607806471092736]
# recall_score_weighted                               [0.8971168437025797]
#
#                                  d1860d72-7c14-419f-be9b-32d90bb2b64d_30  \
# balanced_accuracy                                   [0.6970160063869948]
# f1_score_weighted                                   [0.8997085554096259]
# norm_macro_recall                                   [0.3940320127739896]
# f1_score_macro                                       [0.728593197597418]
# matthews_correlation                               [0.47012920187970497]
# weighted_accuracy                                   [0.9600558174593857]
# average_precision_score_macro                       [0.8011197838098786]
# precision_score_micro                               [0.9077389984825494]
# precision_score_weighted                            [0.8968177807492936]
# average_precision_score_micro                       [0.9789336982903197]
# log_loss                                           [0.18617286531974958]
# average_precision_score_weighted                    [0.9494763098174126]
# AUC_macro                                           [0.9394995248653786]
# AUC_weighted                                        [0.9394995248653786]
# f1_score_micro                                      [0.9077389984825494]
# accuracy                                            [0.9077389984825494]
# recall_score_micro                                  [0.9077389984825494]
# AUC_micro                                           [0.9778524964251257]
# precision_score_macro                                [0.780461306816234]
# recall_score_macro                                  [0.6970160063869948]
# recall_score_weighted                               [0.9077389984825494]
#
#                                  d1860d72-7c14-419f-be9b-32d90bb2b64d_35  \
# balanced_accuracy                                   [0.8549866906734686]
# f1_score_weighted                                    [0.865744059461436]
# norm_macro_recall                                   [0.7099733813469371]
# f1_score_macro                                      [0.7297057544239853]
# matthews_correlation                                [0.5246423870308218]
# weighted_accuracy                                   [0.8405222016048728]
# average_precision_score_macro                       [0.7556077461745458]
# precision_score_micro                               [0.8433990895295903]
# precision_score_weighted                             [0.916564729149542]
# average_precision_score_micro                       [0.8831305811967652]
# log_loss                                            [0.4023623110439046]
# average_precision_score_weighted                    [0.9376053638719782]
# AUC_macro                                           [0.9244350714183833]
# AUC_weighted                                        [0.9244350714183834]
# f1_score_micro                                      [0.8433990895295903]
# accuracy                                            [0.8433990895295903]
# recall_score_micro                                  [0.8433990895295903]
# AUC_micro                                           [0.9106307667155598]
# precision_score_macro                               [0.6938450380683319]
# recall_score_macro                                  [0.8549866906734686]
# recall_score_weighted                               [0.8433990895295903]
#
#                                  d1860d72-7c14-419f-be9b-32d90bb2b64d_4  \
# balanced_accuracy                                  [0.6296552541738678]
# f1_score_weighted                                  [0.8840616198934864]
# norm_macro_recall                                  [0.2593105083477356]
# f1_score_macro                                     [0.6676069493741826]
# matthews_correlation                               [0.3793219953794519]
# weighted_accuracy                                  [0.9692028995921537]
# average_precision_score_macro                      [0.7611421460271339]
# precision_score_micro                              [0.9016691957511381]
# precision_score_weighted                           [0.8842860209793224]
# average_precision_score_micro                      [0.9679356183940777]
# log_loss                                           [0.3677699285396721]
# average_precision_score_weighted                   [0.9350362755968085]
# AUC_macro                                          [0.9094641629943299]
# AUC_weighted                                         [0.90946416299433]
# f1_score_micro                                      [0.901669195751138]
# accuracy                                           [0.9016691957511381]
# recall_score_micro                                 [0.9016691957511381]
# AUC_micro                                          [0.9696666444076532]
# precision_score_macro                              [0.7774379972015998]
# recall_score_macro                                 [0.6296552541738678]
# recall_score_weighted                              [0.9016691957511381]
#
#                                  d1860d72-7c14-419f-be9b-32d90bb2b64d_20  \
# balanced_accuracy                                   [0.7224236681874678]
# f1_score_weighted                                   [0.7579320774824435]
# norm_macro_recall                                   [0.4448473363749357]
# f1_score_macro                                      [0.5845512548138593]
# matthews_correlation                               [0.29406957939934797]
# weighted_accuracy                                   [0.7003048069262952]
# average_precision_score_macro                       [0.6624263698992771]
# precision_score_micro                               [0.7047040971168437]
# precision_score_weighted                            [0.8757110993587777]
# average_precision_score_micro                       [0.7218733976464158]
# log_loss                                             [0.555367536528781]
# average_precision_score_weighted                    [0.8988000142574671]
# AUC_macro                                           [0.8139046804001875]
# AUC_weighted                                        [0.8139046804001875]
# f1_score_micro                                      [0.7047040971168437]
# accuracy                                            [0.7047040971168437]
# recall_score_micro                                  [0.7047040971168437]
# AUC_micro                                           [0.7814947464890243]
# precision_score_macro                               [0.5971984211851311]
# recall_score_macro                                  [0.7224236681874678]
# recall_score_weighted                               [0.7047040971168437]
#
#                                  d1860d72-7c14-419f-be9b-32d90bb2b64d_21  \
# balanced_accuracy                                   [0.7244742491854173]
# f1_score_weighted                                   [0.7607542260297769]
# norm_macro_recall                                   [0.4489484983708345]
# f1_score_macro                                      [0.5873934391218353]
# matthews_correlation                                [0.2975033088840699]
# weighted_accuracy                                   [0.7043417654703226]
# average_precision_score_macro                       [0.7143518521956895]
# precision_score_micro                               [0.7083459787556904]
# precision_score_weighted                            [0.8762088257269456]
# average_precision_score_micro                       [0.8177213267865457]
# log_loss                                            [0.5386692915596978]
# average_precision_score_weighted                    [0.9203151005659512]
# AUC_macro                                           [0.8595189933444106]
# AUC_weighted                                        [0.8595189933444106]
# f1_score_micro                                      [0.7083459787556904]
# accuracy                                            [0.7083459787556904]
# recall_score_micro                                  [0.7083459787556904]
# AUC_micro                                           [0.8229745257103119]
# precision_score_macro                               [0.5985727974568944]
# recall_score_macro                                  [0.7244742491854173]
# recall_score_weighted                               [0.7083459787556904]
#
#                                  d1860d72-7c14-419f-be9b-32d90bb2b64d_24  \
# balanced_accuracy                                   [0.7445521601490792]
# f1_score_weighted                                   [0.9056577488524223]
# norm_macro_recall                                   [0.4891043202981584]
# f1_score_macro                                      [0.7569314175488706]
# matthews_correlation                                [0.5151766229945487]
# weighted_accuracy                                   [0.9486327148396743]
# average_precision_score_macro                       [0.8139354179020992]
# precision_score_micro                               [0.9080424886191198]
# precision_score_weighted                            [0.9037941765081041]
# average_precision_score_micro                       [0.9797430783492997]
# log_loss                                           [0.18369916239363407]
# average_precision_score_weighted                    [0.9524128699963818]
# AUC_macro                                           [0.9409323382365744]
# AUC_weighted                                        [0.9409323382365743]
# f1_score_micro                                        [0.90804248861912]
# accuracy                                            [0.9080424886191198]
# recall_score_micro                                  [0.9080424886191198]
# AUC_micro                                            [0.978771624823559]
# precision_score_macro                               [0.7713193708024036]
# recall_score_macro                                  [0.7445521601490792]
# recall_score_weighted                               [0.9080424886191198]
#
#                                  d1860d72-7c14-419f-be9b-32d90bb2b64d_25
# balanced_accuracy                                   [0.7555751907484898]
# f1_score_weighted                                   [0.9105214923382681]
# norm_macro_recall                                   [0.5111503814969796]
# f1_score_macro                                      [0.7691825165821541]
# matthews_correlation                                [0.5398649524892071]
# weighted_accuracy                                    [0.951957410961161]
# average_precision_score_macro                       [0.8117468850807403]
# precision_score_micro                               [0.9128983308042489]
# precision_score_weighted                             [0.908739808485468]
# average_precision_score_micro                       [0.9792423403521983]
# log_loss                                           [0.19211075143224646]
# average_precision_score_weighted                    [0.9518344397613885]
# AUC_macro                                           [0.9402691873808691]
# AUC_weighted                                        [0.9402691873808691]
# f1_score_micro                                      [0.9128983308042489]
# accuracy                                            [0.9128983308042489]
# recall_score_micro                                  [0.9128983308042489]
# AUC_micro                                           [0.9782576718760432]
# precision_score_macro                               [0.7850963018677666]
# recall_score_macro                                  [0.7555751907484898]
# recall_score_weighted                               [0.9128983308042489]
#
# [21 rows x 37 columns]

# %% [markdown]
# ### Retrieve the Best Model

# %%
# Retrieve best model from Pipeline Run
best_model_output = pipeline_run.get_pipeline_output(best_model_output_name)
num_file_downloaded = best_model_output.download('.', show_progress=True)
# Out:
# Downloading azureml/d1860d72-7c14-419f-be9b-32d90bb2b64d/model_data
# Downloaded azureml/d1860d72-7c14-419f-be9b-32d90bb2b64d/model_data, 1 files out of an estimated total of 1

# %%
import pickle

with open(best_model_output._path_on_datastore, "rb" ) as f:
    best_model = pickle.load(f)
best_model
# Out:
# PipelineWithYTransformations(Pipeline={'memory': None,
#                                        'steps': [('datatransformer',
#                                                   DataTransformer(enable_dnn=None,
#                                                                   enable_feature_sweeping=None,
#                                                                   feature_sweeping_config=None,
#                                                                   feature_sweeping_timeout=None,
#                                                                   featurization_config=None,
#                                                                   force_text_dnn=None,
#                                                                   is_cross_validation=None,
#                                                                   is_onnx_compatible=None,
#                                                                   logger=None,
#                                                                   observer=None,
#                                                                   task=None,
#                                                                   working_dir=None))...
#                                                                                                                                    min_samples_split=0.15052631578947367,
#                                                                                                                                    min_weight_fraction_leaf=0.0,
#                                                                                                                                    n_estimators=10,
#                                                                                                                                    n_jobs=1,
#                                                                                                                                    oob_score=False,
#                                                                                                                                    random_state=None,
#                                                                                                                                    verbose=0,
#                                                                                                                                    warm_start=False))],
#                                                                                                       verbose=False))],
#                                                                                 flatten_transform=None,
#                                                                                 weights=[0.5333333333333333,
#                                                                                          0.06666666666666667,
#                                                                                          0.06666666666666667,
#                                                                                          0.06666666666666667,
#                                                                                          0.2,
#                                                                                          0.06666666666666667]))],
#                                        'verbose': False},
#                              y_transformer={},
#                              y_transformer_name='LabelEncoder')

# %%
best_model.steps
# Out:
# [('datatransformer',
#   DataTransformer(enable_dnn=None, enable_feature_sweeping=None,
#                   feature_sweeping_config=None, feature_sweeping_timeout=None,
#                   featurization_config=None, force_text_dnn=None,
#                   is_cross_validation=None, is_onnx_compatible=None, logger=None,
#                   observer=None, task=None, working_dir=None)),
#  ('prefittedsoftvotingclassifier',
#   PreFittedSoftVotingClassifier(classification_labels=None,
#                                 estimators=[('0',
#                                              Pipeline(memory=None,
#                                                       steps=[('maxabsscaler',
#                                                               MaxAbsScaler(copy=True)),
#                                                              ('lightgbmclassifier',
#                                                               LightGBMClassifier(boosting_type='gbdt',
#                                                                                  class_weight=None,
#                                                                                  colsample_bytree=1.0,
#                                                                                  importance_type='split',
#                                                                                  learning_rate=0.1,
#                                                                                  max_depth=-1,
#                                                                                  min_child_samples=20,
#                                                                                  min_child_weight=0.001,
#                                                                                  min_spl...
#                                                                                    min_impurity_split=None,
#                                                                                    min_samples_leaf=0.06157894736842105,
#                                                                                    min_samples_split=0.15052631578947367,
#                                                                                    min_weight_fraction_leaf=0.0,
#                                                                                    n_estimators=10,
#                                                                                    n_jobs=1,
#                                                                                    oob_score=False,
#                                                                                    random_state=None,
#                                                                                    verbose=0,
#                                                                                    warm_start=False))],
#                                                       verbose=False))],
#                                 flatten_transform=None,
#                                 weights=[0.5333333333333333, 0.06666666666666667,
#                                          0.06666666666666667, 0.06666666666666667,
#                                          0.2, 0.06666666666666667]))]

# %% [markdown]
# ### Test the Model
# #### Load Test Data
# For the test data, it should have the same preparation step as the train data. Otherwise it might get failed at the preprocessing step.

# %%
dataset_test = Dataset.Tabular.from_delimited_files(path='https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv')
df_test = dataset_test.to_pandas_dataframe()
df_test = df_test[pd.notnull(df_test['y'])]

y_test = df_test['y']
X_test = df_test.drop(['y'], axis=1)

# %% [markdown]
# #### Testing Our Best Fitted Model
#
# We will use confusion matrix to see how our model works.

# %%
from sklearn.metrics import confusion_matrix
ypred = best_model.predict(X_test)
cm = confusion_matrix(y_test, ypred)

# %%
# Visualize the confusion matrix
pd.DataFrame(cm).style.background_gradient(cmap='Blues', low=0, high=0.9)
# Out:
# <style  type="text/css" >
#     #T_5913095c_2909_11eb_a05d_000d3aee8eb0row0_col0 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }    #T_5913095c_2909_11eb_a05d_000d3aee8eb0row0_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_5913095c_2909_11eb_a05d_000d3aee8eb0row1_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_5913095c_2909_11eb_a05d_000d3aee8eb0row1_col1 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }</style><table id="T_5913095c_2909_11eb_a05d_000d3aee8eb0" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5913095c_2909_11eb_a05d_000d3aee8eb0level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_5913095c_2909_11eb_a05d_000d3aee8eb0row0_col0" class="data row0 col0" >28859</td>
#                         <td id="T_5913095c_2909_11eb_a05d_000d3aee8eb0row0_col1" class="data row0 col1" >399</td>
#             </tr>
#             <tr>
#                         <th id="T_5913095c_2909_11eb_a05d_000d3aee8eb0level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_5913095c_2909_11eb_a05d_000d3aee8eb0row1_col0" class="data row1 col0" >1002</td>
#                         <td id="T_5913095c_2909_11eb_a05d_000d3aee8eb0row1_col1" class="data row1 col1" >2690</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Publish and run from REST endpoint
#
# Run the following code to publish the pipeline to your workspace. In your workspace in the portal, you can see metadata for the pipeline including run history and durations. You can also run the pipeline manually from the portal.
#
# Additionally, publishing the pipeline enables a REST endpoint to rerun the pipeline from any HTTP library on any platform.

# %%
published_pipeline = pipeline_run.publish_pipeline(
    name="Bankmarketing Train", description="Training bankmarketing pipeline", version="1.0")

published_pipeline
# Out:
# Pipeline(Name: Bankmarketing Train,
# Id: 863d7953-66ea-47ca-8403-163a1ca5bce1,
# Status: Active,
# Endpoint: https://southcentralus.api.azureml.ms/pipelines/v1.0/subscriptions/2248b1c7-a065-4265-9476-038b58f0650e/resourceGroups/aml-quickstarts-126656/providers/Microsoft.MachineLearningServices/workspaces/quick-starts-ws-126656/PipelineRuns/PipelineSubmit/863d7953-66ea-47ca-8403-163a1ca5bce1)

# %% [markdown]
# Authenticate once again, to retrieve the `auth_header` so that the endpoint can be used

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()

# %% [markdown]
# Get the REST url from the endpoint property of the published pipeline object. You can also find the REST url in your workspace in the portal. Build an HTTP POST request to the endpoint, specifying your authentication header. Additionally, add a JSON payload object with the experiment name and the batch size parameter. As a reminder, the process_count_per_node is passed through to ParallelRunStep because you defined it is defined as a PipelineParameter object in the step configuration.
#
# Make the request to trigger the run. Access the Id key from the response dict to get the value of the run id.

# %%
import requests

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": "pipeline-rest-endpoint"}
                        )

# %%
try:
    response.raise_for_status()
except Exception:    
    raise Exception("Received bad response from the endpoint: {}\n"
                    "Response Code: {}\n"
                    "Headers: {}\n"
                    "Content: {}".format(rest_endpoint, response.status_code, response.headers, response.content))

run_id = response.json().get('Id')
print('Submitted pipeline run: ', run_id)
# Out:
# Submitted pipeline run:  c7ace364-e513-4a84-924e-d8a347ccc0e2

# %% [markdown]
# Use the run id to monitor the status of the new run. This will take another 10-15 min to run and will look similar to the previous pipeline run, so if you don't need to see another pipeline run, you can skip watching the full output.

# %%
from azureml.pipeline.core.run import PipelineRun
from azureml.widgets import RunDetails

published_pipeline_run = PipelineRun(ws.experiments["pipeline-rest-endpoint"], run_id)
RunDetails(published_pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …
