# %% [markdown]
# # AUTOML EXPERIMENT

# %%
import azureml.core
from azureml.core.workspace import Workspace
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException
from azureml.core import Experiment
from azureml.core.dataset import Dataset
from azureml.train.automl import AutoMLConfig
from azureml.widgets import RunDetails
from azureml.core.model import Model
from azureml.pipeline.core import Pipeline
from azureml.pipeline.core import PipelineData
from azureml.pipeline.steps import ParallelRunStep, ParallelRunConfig
from azureml.core import Environment
from azureml.core.model import InferenceConfig
from azureml.core.datastore import Datastore
from azureml.automl.runtime.onnx_convert import OnnxConverter
from azureml.train.automl import constants
import onnxruntime
import pandas as pd
import joblib
import os
import sys
import json
import requests

# %%
# MODELS
if "models" not in os.listdir():
    os.mkdir("./models")
# OUTPUS
if "outputs" not in os.listdir():
    os.mkdir("./outputs")

# %% [markdown]
# # WORKSPACE AND EXPERIMENT

# %%
# load workspace   (DON'T FORGET TO DOWNLOAD CONFIG.JSON)
ws = Workspace.from_config()
print('Workspace name: ' + ws.name, 
      'Azure region: ' + ws.location, 
      'Resource group: ' + ws.resource_group, sep = '\n')
# Out:
# Workspace name: quick-starts-ws-128108
# Azure region: southcentralus
# Resource group: aml-quickstarts-128108

# %%
# Create experiment
experiment_name = 'deployments-bankmarketing'
project_folder = './deployments-project'
experiment = Experiment(ws, experiment_name)

# %% [markdown]
# # LOAD DATASET AND PRESERVE DATA FOR INFERENCE

# %%
# Create Dataset and register it into Workspace unless it´s already registered
found = False
key = "BankMarketing Dataset"
description_text = "Bank Marketing DataSet for Udacity Course 2"

if key in ws.datasets.keys(): 
        found = True
        dataset = ws.datasets[key] 

if not found:
    example_data = 'https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv'
    dataset = Dataset.Tabular.from_delimited_files(example_data)        
    dataset = dataset.register(workspace=ws,name=key,description=description_text)

# %%
# Keep 0.1% of the data for batch inference
train, examples = dataset.random_split(0.999,seed=42)
# Drop y from inference sample
examples = examples.drop_columns('y')

# %% [markdown]
# # AUTOML EXPERIMENT

# %%
# create or load compute cluster
cluster_name = "aml-cluster"

try:
    compute_target = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing compute target.')
except ComputeTargetException:
    print('Creating a new compute target...')
    compute_config = AmlCompute.provisioning_configuration(vm_size='Standard_D12_V2', min_nodes=1, max_nodes=5)
    compute_target = ComputeTarget.create(ws, cluster_name, compute_config)

compute_target.wait_for_completion(show_output=True)
# Out:
# Creating a new compute target...
# Creating
# Succeeded.............
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %%
# Configure AutoML
automl_settings = {"experiment_timeout_minutes": 15,
                    "max_concurrent_iterations": 5,
                    "primary_metric" : 'AUC_weighted'}
automl_config = AutoMLConfig(compute_target=compute_target,
                             task = "classification",
                             training_data=train,
                             label_column_name="y",   
                             path = project_folder,
                             enable_early_stopping= True,
                             featurization= 'auto',
                             debug_log = "automl_errors.log",
                             enable_onnx_compatible_models=True,
                             **automl_settings)

# %%
# Run the experiment and show details
deployments_run = experiment.submit(automl_config, show_output = True)
#RunDetails(deployments_run).show()
# Out:
# Running on remote.
# Running on remote compute: aml-cluster
# Parent Run ID: AutoML_e28797ba-b58f-40d7-ade4-691014ee52eb
#
# Current status: FeaturesGeneration. Generating features for the dataset.
# Current status: DatasetFeaturization. Beginning to fit featurizers and featurize the dataset.
# Current status: DatasetBalancing. Performing class balancing sweeping
# Current status: ModelSelection. Beginning model selection.
#
# ****************************************************************************************************
# DATA GUARDRAILS:
#
# TYPE:         Train-Test data split
# STATUS:       DONE
# DESCRIPTION:  Your input data has been split into a training dataset and a holdout test dataset for validation of the model. The test holdout dataset reflects the original distribution of your input data.
#
# DETAILS:
# +---------------------------------+---------------------------------+---------------------------------+
# |Dataset                          |Row counts                       |Percentage                       |
# +=================================+=================================+=================================+
# |train                            |29623                            |89.99848093574359                |
# |test                             |3292                             |10.001519064256419               |
# +---------------------------------+---------------------------------+---------------------------------+
#
# ****************************************************************************************************
#
# TYPE:         Class balancing detection
# STATUS:       ALERTED
# DESCRIPTION:  To decrease model bias, please cancel the current run and fix balancing problem.
#               Learn more about imbalanced data: https://aka.ms/AutomatedMLImbalancedData
# DETAILS:      Imbalanced data can lead to a falsely perceived positive effect of a model's accuracy because the input data has bias towards one class.
# +---------------------------------+---------------------------------+--------------------------------------+
# |Size of the smallest class       |Name/Label of the smallest class |Number of samples in the training data|
# +=================================+=================================+======================================+
# |3321                             |yes                              |29623                                 |
# +---------------------------------+---------------------------------+--------------------------------------+
#
# ****************************************************************************************************
#
# TYPE:         High cardinality feature detection
# STATUS:       PASSED
# DESCRIPTION:  Your inputs were analyzed, and no high cardinality features were detected.
#               Learn more about high cardinality feature handling: https://aka.ms/AutomatedMLFeaturization
#
# ****************************************************************************************************
#
# ****************************************************************************************************
# ITERATION: The iteration being evaluated.
# PIPELINE: A summary description of the pipeline being evaluated.
# DURATION: Time taken for the current iteration.
# METRIC: The result of computing score on the fitted pipeline.
# BEST: The best observed score thus far.
# ****************************************************************************************************
#
#  ITERATION   PIPELINE                                       DURATION      METRIC      BEST
#          4   MaxAbsScaler SGD                               0:00:34       0.9263    0.9263
#          0   MaxAbsScaler LightGBM                          0:00:37       0.9500    0.9500
#          1   MaxAbsScaler XGBoostClassifier                 0:00:34       0.9479    0.9500
#          2   MaxAbsScaler RandomForest                      0:00:11       0.9002    0.9500
#          7   MaxAbsScaler SGD                               0:00:33       0.9333    0.9500
#          8   MaxAbsScaler RandomForest                      0:00:32       0.8818    0.9500
#          3   MaxAbsScaler SGD                               0:01:51       0.9301    0.9500
#          6   MaxAbsScaler ExtremeRandomTrees                0:02:05       0.9084    0.9500
#         11   MaxAbsScaler SGD                               0:00:36       0.9340    0.9500
#          5   MaxAbsScaler ExtremeRandomTrees                0:02:52       0.9008    0.9500
#          9   MaxAbsScaler SGD                               0:00:22       0.9224    0.9500
#         10   MaxAbsScaler RandomForest                      0:00:13       0.8885    0.9500
#         12   MaxAbsScaler SGD                               0:00:41       0.9251    0.9500
#         13   MaxAbsScaler RandomForest                      0:00:36       0.8159    0.9500
#         14   StandardScalerWrapper ExtremeRandomTrees       0:00:40       0.8957    0.9500
#         16   SparseNormalizer ExtremeRandomTrees            0:00:36       0.8619    0.9500
#         15   SparseNormalizer ExtremeRandomTrees            0:00:31       0.9259    0.9500
#         17   MaxAbsScaler SGD                               0:00:33       0.9108    0.9500
#         18   MaxAbsScaler SGD                               0:00:28       0.9095    0.9500
#         19   MaxAbsScaler RandomForest                      0:00:26       0.8614    0.9500
#         20   MaxAbsScaler ExtremeRandomTrees                0:00:33       0.8385    0.9500
#         21   MaxAbsScaler ExtremeRandomTrees                0:00:25       0.8068    0.9500
#         22   MaxAbsScaler ExtremeRandomTrees                0:00:40       0.8064    0.9500
#         23   MaxAbsScaler ExtremeRandomTrees                0:00:27       0.8990    0.9500
#         24   SparseNormalizer XGBoostClassifier             0:00:34       0.9507    0.9507
#         25   MaxAbsScaler LightGBM                          0:00:31       0.9473    0.9507
#         26   StandardScalerWrapper SGD                      0:00:33       0.5342    0.9507
#         27   MaxAbsScaler LightGBM                          0:00:39       0.9273    0.9507
#         28   MaxAbsScaler LightGBM                          0:00:31       0.9346    0.9507
#         31   SparseNormalizer XGBoostClassifier             0:00:05       0.9465    0.9507
#         29   SparseNormalizer XGBoostClassifier             0:00:15       0.9290    0.9507
#         34   SparseNormalizer XGBoostClassifier             0:00:42       0.9449    0.9507
#         30   MaxAbsScaler GradientBoosting                  0:00:45       0.9291    0.9507
#         33   TruncatedSVDWrapper LogisticRegression         0:00:12       0.8656    0.9507
#         32   SparseNormalizer LightGBM                      0:00:25       0.9318    0.9507
#         35   SparseNormalizer XGBoostClassifier             0:00:34       0.9426    0.9507
#         36   SparseNormalizer XGBoostClassifier             0:00:34       0.9505    0.9507
#         37   SparseNormalizer XGBoostClassifier             0:00:46       0.9471    0.9507
#         38   StandardScalerWrapper XGBoostClassifier        0:00:32       0.9488    0.9507
#         40   StandardScalerWrapper XGBoostClassifier        0:00:33       0.9500    0.9507
#         39   StandardScalerWrapper XGBoostClassifier        0:00:49          nan    0.9507
#         41   StandardScalerWrapper XGBoostClassifier        0:00:29          nan    0.9507
#         42   SparseNormalizer XGBoostClassifier             0:00:33          nan    0.9507
#         43                                                  0:00:44          nan    0.9507
#         44    VotingEnsemble                                0:00:47       0.9519    0.9519

# %% [markdown]
# ## REGISTER BEST MODEL AND BEST ONNX MODEL

# %%
# Register the best model
model = deployments_run.register_model(model_name='deployments-bankmarketing')
# Save the model
best_run1, fitted_model = deployments_run.get_output()
joblib.dump(fitted_model, filename='models/base_model.joblib')
# Out:
# ['models/base_model.joblib']

# %%
# Get the best ONNX model
best_run2, onnx_model = deployments_run.get_output(return_onnx_model=True)
# Save the model
onnx_path = "./models/best_onnx.onnx"
OnnxConverter.save_onnx_model(onnx_model, onnx_path)
# Register the model
model_onnx = Model.register(workspace=ws, model_name='bankmarketing-onnx', model_path=onnx_path, model_framework=Model.Framework.ONNX,                                       model_framework_version='1.3')

#service_name = 'onnx-bankmarketing'
#service = Model.deploy(ws, service_name, [model_onnx])
# Out:
# Registering model bankmarketing-onnx

# %% [markdown]
# # ONNX

# %%
# Start inference session
session = onnxruntime.InferenceSession(onnx_path)

# %%
# Run the inference
examples_onnx = examples.take(5).to_pandas_dataframe()
try:
    result = session.run([],examples_onnx)
    print(result)
except Exception as e:
    result = str(e)
    print(result)
# Out:
# Model requires 20 inputs. Input Feed contains 5

# %%
# One data for ONNX                             

data1 =  {
            "age": 17,
            "campaign": 1,
            "cons.conf.idx": -46.2,
            "cons.price.idx": 92.893,
            "contact": "cellular",
            "day_of_week": "mon",
            "default": "no",
            "duration": 971,
            "education": "university.degree",
            "emp.var.rate": -1.8,
            "euribor3m": 1.299,
            "housing": "yes",
            "job": "blue-collar",
            "loan": "yes",
            "marital": "married",
            "month": "may",
            "nr.employed": 5099.1,
            "pdays": 999,
            "poutcome": "failure",
            "previous": 1
          }



pred = session.run([],data1)  
print(pred)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-36-fa095d58102d> in <module>
#      26
#      27
# ---> 28 pred = session.run([],data1)
#      29 print(pred)
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/onnxruntime/capi/session.py in run(self, output_names, input_feed, run_options)
#     109             output_names = [output.name for output in self._outputs_meta]
#     110         try:
# --> 111             return self._sess.run(output_names, input_feed, run_options)
#     112         except C.EPFail as err:
#     113             if self._enable_fallback:
#
# RuntimeError: Unable to handle object of type <class 'int'>

# %% [markdown]
# # DOCKER

# %%
# Prepare to build an image
### NOTE: download the model and extract into ./models)
model = Model(ws, 'deployments-bankmarketing')   
env = Environment.from_conda_specification('docker', './models/conda_env_v_1_0_0.yml')
inference_config = InferenceConfig(entry_script='./models/scoring_file_v_1_0_0.py', environment=env)

# %% [markdown]
# ### BUILD AN IMAGE AND PULL IT

# %%
# Build a standard image and pull it
package = Model.package(ws, [model], inference_config)   
package.wait_for_creation(show_output=True)    
package.pull()
# Out:
# 2020/11/27 17:27:10 Downloading source code...
# 2020/11/27 17:27:11 Finished downloading source code
# 2020/11/27 17:27:12 Creating Docker network: acb_default_network, driver: 'bridge'
# 2020/11/27 17:27:12 Successfully set up Docker network: acb_default_network
# 2020/11/27 17:27:12 Setting up Docker configuration...
# 2020/11/27 17:27:13 Successfully set up Docker configuration
# 2020/11/27 17:27:13 Logging in to registry: b4ebf977fa1b4412adb84bc5f3bef665.azurecr.io
# 2020/11/27 17:27:15 Successfully logged into b4ebf977fa1b4412adb84bc5f3bef665.azurecr.io
# 2020/11/27 17:27:15 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2020/11/27 17:27:15 Scanning for dependencies...
# 2020/11/27 17:27:16 Successfully scanned dependencies
# 2020/11/27 17:27:16 Launching container with name: acb_step_0
# Sending build context to Docker daemon     64kB
# Step 1/15 : FROM mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200821.v1@sha256:8cee6f674276dddb23068d2710da7f7f95b119412cc482675ac79ba45a4acf99
# sha256:8cee6f674276dddb23068d2710da7f7f95b119412cc482675ac79ba45a4acf99: Pulling from azureml/intelmpi2018.3-ubuntu16.04
# Digest: sha256:8cee6f674276dddb23068d2710da7f7f95b119412cc482675ac79ba45a4acf99
# Status: Downloaded newer image for mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200821.v1@sha256:8cee6f674276dddb23068d2710da7f7f95b119412cc482675ac79ba45a4acf99
#  ---> 287916b809d9
# Step 2/15 : USER root
#  ---> Running in c060182dd423
# Removing intermediate container c060182dd423
#  ---> f8c4d106ca3e
# Step 3/15 : RUN mkdir -p $HOME/.cache
#  ---> Running in d86db689695e
# Removing intermediate container d86db689695e
#  ---> 76c6afd5e9cb
# Step 4/15 : WORKDIR /
#  ---> Running in d6750146f15a
# Removing intermediate container d6750146f15a
#  ---> f7727f5a4849
# Step 5/15 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> ef2996440cd3
# Step 6/15 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in 7ad95c2552f4
# Removing intermediate container 7ad95c2552f4
#  ---> 4be56f005b25
# Step 7/15 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> 1a1929e393ec
# Step 8/15 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_28fee3619d571f61730f3ee3b96a407c -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in 8d7f74a46bc5
# Warning: you have pip-installed dependencies in your environment file, but you do not list pip itself as one of your conda dependencies.  Conda may not use the correct pip to install your packages, and they may end up in the wrong place.  Please add an explicit pip dependency.  I'm adding one for you, but still nagging you.
# Collecting package metadata (repodata.json): ...working...
# done
# Solving environment: ...working...
# done
#
# Downloading and Extracting Packages
# pandas-0.25.1        | 11.4 MB   | ########## | 100%
# expat-2.2.10         | 192 KB    | ########## | 100%
# libxcb-1.14          | 610 KB    | ########## | 100%
# gst-plugins-base-1.1 | 6.3 MB    | ########## | 100%
# setuptools-50.3.0    | 891 KB    | ########## | 100%
# readline-7.0         | 387 KB    | ########## | 100%
# matplotlib-3.3.1     | 24 KB     | ########## | 100%
# libuuid-1.0.3        | 16 KB     | ########## | 100%
# ca-certificates-2020 | 128 KB    | ########## | 100%
# libtiff-4.1.0        | 607 KB    | ########## | 100%
# libxml2-2.9.10       | 1.3 MB    | ########## | 100%
# intel-openmp-2020.2  | 947 KB    | ########## | 100%
# cycler-0.10.0        | 13 KB     | ########## | 100%
# libedit-3.1          | 171 KB    | ########## | 100%
# python-3.6.2         | 27.0 MB   | ########## | 100%
# scipy-1.5.2          | 18.5 MB   | ########## | 100%
# scikit-learn-0.22.1  | 7.1 MB    | ########## | 100%
# gxx_impl_linux-64-7. | 18.7 MB   | ########## | 100%
# zlib-1.2.11          | 120 KB    | ########## | 100%
# _py-xgboost-mutex-2. | 9 KB      | ########## | 100%
# py-xgboost-0.90      | 77 KB     | ########## | 100%
# mkl_fft-1.2.0        | 164 KB    | ########## | 100%
# libgfortran-ng-7.3.0 | 1.3 MB    | ########## | 100%
# convertdate-2.3.0    | 36 KB     | ########## | 100%
# cython-0.29.21       | 2.1 MB    | ########## | 100%
# pcre-8.44            | 269 KB    | ########## | 100%
# pymeeus-0.3.7        | 515 KB    | ########## | 100%
# ncurses-6.0          | 907 KB    | ########## | 100%
# kiwisolver-1.2.0     | 91 KB     | ########## | 100%
# wheel-0.35.1         | 36 KB     | ########## | 100%
# mkl-2019.4           | 204.1 MB  | #########5 |  96%
# mkl-2019.4           | 204.1 MB  | ########## | 100%
# fbprophet-0.5        | 631 KB    | ########## | 100%
# gcc_linux-64-7.3.0   | 25 KB     | ########## | 100%
# blas-1.0             | 6 KB      | ########## | 100%
# numpy-1.18.5         | 4 KB      | ########## | 100%
# tk-8.6.10            | 3.2 MB    | ########## | 100%
# pystan-2.19.0.0      | 16.6 MB   | ########## | 100%
# matplotlib-base-3.3. | 6.7 MB    | ########## | 100%
# gcc_impl_linux-64-7. | 73.2 MB   | ########## | 100%
# jpeg-9b              | 247 KB    | ########## | 100%
# libgcc-ng-9.1.0      | 8.1 MB    | ########## | 100%
# olefile-0.46         | 48 KB     | ########## | 100%
# openssl-1.0.2u       | 3.1 MB    | ########## | 100%
# pytz-2020.1          | 239 KB    | ########## | 100%
# zstd-1.4.4           | 1006 KB   | ########## | 100%
# dbus-1.13.18         | 586 KB    | ########## | 100%
# gstreamer-1.14.0     | 3.8 MB    | ########## | 100%
# sip-4.19.24          | 297 KB    | ########## | 100%
# libpng-1.6.37        | 364 KB    | ########## | 100%
# pillow-8.0.0         | 675 KB    | ########## | 100%
# six-1.15.0           | 13 KB     | ########## | 100%
# xz-5.2.5             | 438 KB    | ########## | 100%
# libffi-3.2.1         | 52 KB     | ########## | 100%
# mkl_random-1.1.0     | 369 KB    | ########## | 100%
# numpy-base-1.18.5    | 5.1 MB    | ########## | 100%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
# fontconfig-2.13.0    | 291 KB    | ########## | 100%
# lcms2-2.11           | 419 KB    | ########## | 100%
# freetype-2.10.4      | 901 KB    | ########## | 100%
# gxx_linux-64-7.3.0   | 24 KB     | ########## | 100%
# binutils_impl_linux- | 16.5 MB   | ########## | 100%
# icu-58.2             | 22.7 MB   | ########## | 100%
# pip-20.2.4           | 2.0 MB    | ########## | 100%
# pyqt-5.9.2           | 5.6 MB    | ########## | 100%
# mkl-service-2.3.0    | 208 KB    | ########## | 100%
# tornado-6.0.4        | 650 KB    | ########## | 100%
# lunardate-0.2.0      | 21 KB     | ########## | 100%
# libxgboost-0.90      | 3.8 MB    | ########## | 100%
# holidays-0.9.11      | 39 KB     | ########## | 100%
# pyparsing-2.4.7      | 64 KB     | ########## | 100%
# lz4-c-1.9.2          | 203 KB    | ########## | 100%
# certifi-2020.6.20    | 160 KB    | ########## | 100%
# glib-2.56.2          | 5.0 MB    | ########## | 100%
# psutil-5.7.2         | 342 KB    | ########## | 100%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ########## | 100%
# joblib-0.17.0        | 205 KB    | ########## | 100%
# binutils_linux-64-2. | 24 KB     | ########## | 100%
# qt-5.9.6             | 86.7 MB   | #########4 |  95%
# qt-5.9.6             | 86.7 MB   | ########## | 100%
# python-dateutil-2.8. | 224 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_28fee3619d571f61730f3ee3b96a407c/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.b9e_95og.requirements.txt']
# Pip subprocess output:
# Collecting azureml-train-automl-runtime==1.17.0
#   Downloading azureml_train_automl_runtime-1.17.0-py3-none-any.whl (119 kB)
# Collecting inference-schema
#   Downloading inference_schema-1.1.0-py3-none-any.whl (19 kB)
# Collecting azureml-interpret==1.17.0
#   Downloading azureml_interpret-1.17.0-py3-none-any.whl (46 kB)
# Collecting azureml-defaults==1.17.0
#   Downloading azureml_defaults-1.17.0-py3-none-any.whl (3.0 kB)
# Collecting azureml-dataset-runtime[fuse,pandas]~=1.17.0
#   Downloading azureml_dataset_runtime-1.17.0-py3-none-any.whl (3.4 kB)
# Collecting onnx<=1.6.0,>=1.5.0
#   Downloading onnx-1.6.0-cp36-cp36m-manylinux1_x86_64.whl (4.8 MB)
# Collecting sklearn-pandas<=1.7.0,>=1.4.0
#   Downloading sklearn_pandas-1.7.0-py2.py3-none-any.whl (10 kB)
# Collecting skl2onnx==1.4.9
#   Downloading skl2onnx-1.4.9-py2.py3-none-any.whl (114 kB)
# Collecting azureml-core~=1.17.0
#   Downloading azureml_core-1.17.0-py3-none-any.whl (2.1 MB)
# Requirement already satisfied, skipping upgrade: pandas<1.0.0,>=0.21.0 in /azureml-envs/azureml_28fee3619d571f61730f3ee3b96a407c/lib/python3.6/site-packages (from azureml-train-automl-runtime==1.17.0->-r /azureml-environment-setup/condaenv.b9e_95og.requirements.txt (line 1)) (0.25.1)
# Collecting onnxconverter-common<=1.6.0,>=1.4.2
#   Downloading onnxconverter_common-1.6.0-py2.py3-none-any.whl (43 kB)
# Collecting statsmodels<=0.10.2,>=0.9.0
#   Downloading statsmodels-0.10.2-cp36-cp36m-manylinux1_x86_64.whl (8.1 MB)
# Collecting gensim<3.9.0
#   Downloading gensim-3.8.3-cp36-cp36m-manylinux1_x86_64.whl (24.2 MB)
# Collecting lightgbm<=2.3.0,>=2.0.11
#   Downloading lightgbm-2.3.0-py2.py3-none-manylinux1_x86_64.whl (1.3 MB)
# Collecting keras2onnx<=1.6.0,>=1.4.0
#   Downloading keras2onnx-1.6.0-py3-none-any.whl (219 kB)
# Collecting smart-open<=1.9.0
#   Downloading smart_open-1.9.0.tar.gz (70 kB)
# Collecting onnxmltools==1.4.1
#   Downloading onnxmltools-1.4.1-py2.py3-none-any.whl (371 kB)
# Collecting azureml-telemetry~=1.17.0
#   Downloading azureml_telemetry-1.17.0-py3-none-any.whl (30 kB)
# Requirement already satisfied, skipping upgrade: scipy<=1.5.2,>=1.0.0 in /azureml-envs/azureml_28fee3619d571f61730f3ee3b96a407c/lib/python3.6/site-packages (from azureml-train-automl-runtime==1.17.0->-r /azureml-environment-setup/condaenv.b9e_95og.requirements.txt (line 1)) (1.5.2)
# Collecting azureml-train-automl-client~=1.17.0
#   Downloading azureml_train_automl_client-1.17.0-py3-none-any.whl (108 kB)
# Requirement already satisfied, skipping upgrade: scikit-learn<0.23.0,>=0.19.0 in /azureml-envs/azureml_28fee3619d571f61730f3ee3b96a407c/lib/python3.6/site-packages (from azureml-train-automl-runtime==1.17.0->-r /azureml-environment-setup/condaenv.b9e_95og.requirements.txt (line 1)) (0.22.1)
# Collecting azureml-automl-runtime~=1.17.0
#   Downloading azureml_automl_runtime-1.17.0-py3-none-any.whl (1.9 MB)
# Requirement already satisfied, skipping upgrade: numpy<1.19.0,>=1.16.0 in /azureml-envs/azureml_28fee3619d571f61730f3ee3b96a407c/lib/python3.6/site-packages (from azureml-train-automl-runtime==1.17.0->-r /azureml-environment-setup/condaenv.b9e_95og.requirements.txt (line 1)) (1.18.5)
# Collecting azure-storage-queue~=12.1
#   Downloading azure_storage_queue-12.1.4-py2.py3-none-any.whl (131 kB)
# Collecting azureml-automl-core~=1.17.0
#   Downloading azureml_automl_core-1.17.0-py3-none-any.whl (181 kB)
# Collecting jinja2<=2.11.2
#   Downloading Jinja2-2.11.2-py2.py3-none-any.whl (125 kB)
# Collecting onnxruntime==1.3.0
#   Downloading onnxruntime-1.3.0-cp36-cp36m-manylinux1_x86_64.whl (3.9 MB)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /azureml-envs/azureml_28fee3619d571f61730f3ee3b96a407c/lib/python3.6/site-packages (from inference-schema->-r /azureml-environment-setup/condaenv.b9e_95og.requirements.txt (line 2)) (2020.1)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.5.3 in /azureml-envs/azureml_28fee3619d571f61730f3ee3b96a407c/lib/python3.6/site-packages (from inference-schema->-r /azureml-environment-setup/condaenv.b9e_95og.requirements.txt (line 2)) (2.8.1)
# Collecting wrapt==1.11.1
#   Downloading wrapt-1.11.1.tar.gz (27 kB)
# Collecting interpret-community==0.15.*
#   Downloading interpret_community-0.15.4-py3-none-any.whl (5.9 MB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting applicationinsights>=0.11.7
#   Downloading applicationinsights-0.11.9-py2.py3-none-any.whl (58 kB)
# Collecting azureml-model-management-sdk==1.0.1b6.post1
#   Downloading azureml_model_management_sdk-1.0.1b6.post1-py2.py3-none-any.whl (130 kB)
# Collecting gunicorn==19.9.0
#   Downloading gunicorn-19.9.0-py2.py3-none-any.whl (112 kB)
# Collecting werkzeug<=1.0.1,>=0.16.1
#   Downloading Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
# Collecting flask==1.0.3
#   Downloading Flask-1.0.3-py2.py3-none-any.whl (92 kB)
# Collecting azureml-dataprep<2.5.0a,>=2.4.0a
#   Downloading azureml_dataprep-2.4.4-py3-none-any.whl (28.2 MB)
# Collecting pyarrow<2.0.0,>=0.17.0
#   Downloading pyarrow-1.0.1-cp36-cp36m-manylinux2014_x86_64.whl (17.3 MB)
# Collecting fusepy<4.0.0,>=3.0.1; extra == "fuse"
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Collecting protobuf
#   Downloading protobuf-3.14.0-cp36-cp36m-manylinux1_x86_64.whl (1.0 MB)
# Collecting typing-extensions>=3.6.2.1
#   Downloading typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# Requirement already satisfied, skipping upgrade: six in /azureml-envs/azureml_28fee3619d571f61730f3ee3b96a407c/lib/python3.6/site-packages (from onnx<=1.6.0,>=1.5.0->azureml-train-automl-runtime==1.17.0->-r /azureml-environment-setup/condaenv.b9e_95og.requirements.txt (line 1)) (1.15.0)
# Collecting azure-mgmt-resource<15.0.0,>=1.2.1
#   Downloading azure_mgmt_resource-10.3.0-py2.py3-none-any.whl (1.0 MB)
# Collecting SecretStorage
#   Downloading SecretStorage-3.3.0-py3-none-any.whl (14 kB)
# Collecting azure-common>=1.1.12
#   Downloading azure_common-1.1.26-py2.py3-none-any.whl (12 kB)
# Collecting urllib3>=1.23
#   Downloading urllib3-1.26.2-py2.py3-none-any.whl (136 kB)
# Collecting msrestazure>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-2.8.0-py2.py3-none-any.whl (718 kB)
# Collecting pyopenssl<20.0.0
#   Downloading pyOpenSSL-19.1.0-py2.py3-none-any.whl (53 kB)
# Collecting docker
#   Downloading docker-4.4.0-py2.py3-none-any.whl (146 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting azure-mgmt-keyvault<7.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-2.2.0-py2.py3-none-any.whl (89 kB)
# Collecting ruamel.yaml>=0.15.35
#   Downloading ruamel.yaml-0.16.12-py2.py3-none-any.whl (111 kB)
# Collecting adal>=1.2.0
#   Downloading adal-1.2.5-py2.py3-none-any.whl (55 kB)
# Collecting azure-mgmt-storage<16.0.0,>=1.5.0
#   Downloading azure_mgmt_storage-11.2.0-py2.py3-none-any.whl (547 kB)
# Collecting PyJWT
#   Downloading PyJWT-1.7.1-py2.py3-none-any.whl (18 kB)
# Collecting pathspec
#   Downloading pathspec-0.8.1-py2.py3-none-any.whl (28 kB)
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting jmespath
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting jsonpickle
#   Downloading jsonpickle-1.4.1-py2.py3-none-any.whl (36 kB)
# Collecting azure-mgmt-authorization<1.0.0,>=0.40.0
#   Downloading azure_mgmt_authorization-0.61.0-py2.py3-none-any.whl (94 kB)
# Collecting contextlib2
#   Downloading contextlib2-0.6.0.post1-py2.py3-none-any.whl (9.8 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*
#   Downloading cryptography-3.2.1-cp35-abi3-manylinux2010_x86_64.whl (2.6 MB)
# Collecting msrest>=0.5.1
#   Downloading msrest-0.6.19-py2.py3-none-any.whl (84 kB)
# Collecting ndg-httpsclient
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting requests>=2.19.1
#   Downloading requests-2.25.0-py2.py3-none-any.whl (61 kB)
# Collecting patsy>=0.4.0
#   Downloading patsy-0.5.1-py2.py3-none-any.whl (231 kB)
# Collecting fire
#   Downloading fire-0.3.1.tar.gz (81 kB)
# Collecting boto>=2.32
#   Downloading boto-2.49.0-py2.py3-none-any.whl (1.4 MB)
# Collecting boto3
#   Downloading boto3-1.16.25-py2.py3-none-any.whl (129 kB)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in /azureml-envs/azureml_28fee3619d571f61730f3ee3b96a407c/lib/python3.6/site-packages (from scikit-learn<0.23.0,>=0.19.0->azureml-train-automl-runtime==1.17.0->-r /azureml-environment-setup/condaenv.b9e_95og.requirements.txt (line 1)) (0.17.0)
# Requirement already satisfied, skipping upgrade: psutil<6.0.0,>=5.2.2 in /azureml-envs/azureml_28fee3619d571f61730f3ee3b96a407c/lib/python3.6/site-packages (from azureml-automl-runtime~=1.17.0->azureml-train-automl-runtime==1.17.0->-r /azureml-environment-setup/condaenv.b9e_95og.requirements.txt (line 1)) (5.7.2)
# Collecting dill<0.4.0,>=0.2.8
#   Downloading dill-0.3.3-py2.py3-none-any.whl (81 kB)
# Collecting pmdarima==1.1.1
#   Downloading pmdarima-1.1.1-cp36-cp36m-manylinux1_x86_64.whl (682 kB)
# Collecting nimbusml<=1.8.0,>=1.7.1
#   Downloading nimbusml-1.8.0-cp36-none-manylinux1_x86_64.whl (114.1 MB)
# Collecting py-cpuinfo==5.0.0
#   Downloading py-cpuinfo-5.0.0.tar.gz (82 kB)
# Collecting azure-core<2.0.0,>=1.9.0
#   Downloading azure_core-1.9.0-py2.py3-none-any.whl (124 kB)
# Collecting MarkupSafe>=0.23
#   Downloading MarkupSafe-1.1.1-cp36-cp36m-manylinux1_x86_64.whl (27 kB)
# Collecting packaging
#   Downloading packaging-20.4-py2.py3-none-any.whl (37 kB)
# Collecting interpret-core[required]<=0.2.1,>=0.1.20
#   Downloading interpret_core-0.2.1-py3-none-any.whl (5.0 MB)
# Collecting shap<=0.34.0,>=0.20.0
#   Downloading shap-0.34.0.tar.gz (264 kB)
# Collecting liac-arff>=2.1.1
#   Downloading liac-arff-2.5.0.tar.gz (13 kB)
# Collecting click>=5.1
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting cloudpickle<2.0.0,>=1.1.0
#   Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Collecting azureml-dataprep-native<25.0.0,>=24.0.0
#   Downloading azureml_dataprep_native-24.0.0-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting azureml-dataprep-rslex<1.3.0a,>=1.2.0dev0
#   Downloading azureml_dataprep_rslex-1.2.3-cp36-cp36m-manylinux2010_x86_64.whl (7.9 MB)
# Collecting dotnetcore2<3.0.0,>=2.1.14
#   Downloading dotnetcore2-2.1.19-py3-none-manylinux1_x86_64.whl (28.7 MB)
# Collecting azure-identity<1.5.0,>=1.2.0
#   Downloading azure_identity-1.4.1-py2.py3-none-any.whl (86 kB)
# Collecting jeepney>=0.6
#   Downloading jeepney-0.6.0-py3-none-any.whl (45 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-0.57.0-py2.py3-none-any.whl (200 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.9"
#   Downloading ruamel.yaml.clib-0.2.2-cp36-cp36m-manylinux1_x86_64.whl (549 kB)
# Collecting importlib-metadata
#   Downloading importlib_metadata-3.1.0-py2.py3-none-any.whl (9.3 kB)
# Collecting cffi!=1.11.3,>=1.8
#   Downloading cffi-1.14.4-cp36-cp36m-manylinux1_x86_64.whl (401 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /azureml-envs/azureml_28fee3619d571f61730f3ee3b96a407c/lib/python3.6/site-packages (from msrest>=0.5.1->azureml-core~=1.17.0->azureml-train-automl-runtime==1.17.0->-r /azureml-environment-setup/condaenv.b9e_95og.requirements.txt (line 1)) (2020.6.20)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting idna<3,>=2.5
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
# Collecting chardet<4,>=3.0.2
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# Collecting termcolor
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
# Collecting s3transfer<0.4.0,>=0.3.0
#   Downloading s3transfer-0.3.3-py2.py3-none-any.whl (69 kB)
# Collecting botocore<1.20.0,>=1.19.25
#   Downloading botocore-1.19.25-py2.py3-none-any.whl (6.9 MB)
# Requirement already satisfied, skipping upgrade: Cython>=0.29 in /azureml-envs/azureml_28fee3619d571f61730f3ee3b96a407c/lib/python3.6/site-packages (from pmdarima==1.1.1->azureml-automl-runtime~=1.17.0->azureml-train-automl-runtime==1.17.0->-r /azureml-environment-setup/condaenv.b9e_95og.requirements.txt (line 1)) (0.29.21)
# Requirement already satisfied, skipping upgrade: pyparsing>=2.0.2 in /azureml-envs/azureml_28fee3619d571f61730f3ee3b96a407c/lib/python3.6/site-packages (from packaging->interpret-community==0.15.*->azureml-interpret==1.17.0->-r /azureml-environment-setup/condaenv.b9e_95og.requirements.txt (line 3)) (2.4.7)
# Collecting tqdm>4.25.0
#   Downloading tqdm-4.54.0-py2.py3-none-any.whl (69 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.5.0-py2.py3-none-any.whl (18 kB)
# Collecting msal<2.0.0,>=1.3.0
#   Downloading msal-1.6.0-py2.py3-none-any.whl (50 kB)
# Collecting msal-extensions~=0.2.2
#   Downloading msal_extensions-0.2.2-py2.py3-none-any.whl (15 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.4.0-py3-none-any.whl (5.2 kB)
# Collecting pycparser
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Collecting portalocker~=1.0; platform_system != "Windows"
#   Downloading portalocker-1.7.1-py2.py3-none-any.whl (10 kB)
# Building wheels for collected packages: smart-open, wrapt, json-logging-py, fusepy, fire, py-cpuinfo, shap, liac-arff, termcolor
#   Building wheel for smart-open (setup.py): started
#   Building wheel for smart-open (setup.py): finished with status 'done'
#   Created wheel for smart-open: filename=smart_open-1.9.0-py3-none-any.whl size=73087 sha256=3f09686bf4a3a1c28ef0282b42561e2f1b215f6477137b4002e6c7c750554050
#   Stored in directory: /root/.cache/pip/wheels/8e/9f/cd/dbf5c1362c59abb699a218c1151679033b8ccb5b6db559d512
#   Building wheel for wrapt (setup.py): started
#   Building wheel for wrapt (setup.py): finished with status 'done'
#   Created wheel for wrapt: filename=wrapt-1.11.1-py3-none-any.whl size=19543 sha256=38e1bcf76eca2342f80551f08800811612d8827f4d38b57cb211740c1bf60c2b
#   Stored in directory: /root/.cache/pip/wheels/94/0f/ec/66085641573800014bb0c8b657f3366eff641c42df79abbfe9
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3924 sha256=0dac3b4ef217e1a1260edcd1f9f4fcaab0c43fcc9308ee468647bb31d75712f4
#   Stored in directory: /root/.cache/pip/wheels/e2/1d/52/535a274b9c2ce7d4064838f2bdb62013801281ef7d7f21e2ee
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10504 sha256=c14a22ba73ffe70c14ba1fffe1fa3301f4b26e4511d249122759f46a862783db
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
#   Building wheel for fire (setup.py): started
#   Building wheel for fire (setup.py): finished with status 'done'
#   Created wheel for fire: filename=fire-0.3.1-py2.py3-none-any.whl size=111005 sha256=cf7beac556c525f005fb33c186cbfa915b2142fcc2771de9e2ecab25b173da43
#   Stored in directory: /root/.cache/pip/wheels/3e/38/8f/e5bd4465e4b72c8e4d1530ac46e1a42e1d2495f8c93242d5f1
#   Building wheel for py-cpuinfo (setup.py): started
#   Building wheel for py-cpuinfo (setup.py): finished with status 'done'
#   Created wheel for py-cpuinfo: filename=py_cpuinfo-5.0.0-py3-none-any.whl size=18683 sha256=9d7758769b94c3765df045225e2fe9fe15a22521dbbd09a2e0fea2c41ad3d0d3
#   Stored in directory: /root/.cache/pip/wheels/e6/54/db/65176a1697a583d8ec5f90510f6faab11cda739d0e4f0ba2ea
#   Building wheel for shap (setup.py): started
#   Building wheel for shap (setup.py): finished with status 'done'
#   Created wheel for shap: filename=shap-0.34.0-cp36-cp36m-linux_x86_64.whl size=383882 sha256=ee6131185088912788982b4c96cd40481af731ac20dbea53b347ff3bc32e954d
#   Stored in directory: /root/.cache/pip/wheels/88/56/c6/630b200696678c506f3057a1e7573c086e50d59fdcffcbfd04
#   Building wheel for liac-arff (setup.py): started
#   Building wheel for liac-arff (setup.py): finished with status 'done'
#   Created wheel for liac-arff: filename=liac_arff-2.5.0-py3-none-any.whl size=11730 sha256=a2b517aedf854c04284cf55f52c78839fd433aaa40b29ae5b1f3a1083bdc7331
#   Stored in directory: /root/.cache/pip/wheels/53/ba/da/8562a6a6dbb428fd1ecc21053106df3948645cd991958f669b
#   Building wheel for termcolor (setup.py): started
#   Building wheel for termcolor (setup.py): finished with status 'done'
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4830 sha256=c01540af3d39a8919576f68f75b92480b6c7b779f0e0994f2000a8e7c6b13074
#   Stored in directory: /root/.cache/pip/wheels/93/2a/eb/e58dbcbc963549ee4f065ff80a59f274cc7210b6eab962acdc
# Successfully built smart-open wrapt json-logging-py fusepy fire py-cpuinfo shap liac-arff termcolor
# Installing collected packages: cloudpickle, azureml-dataprep-native, azureml-dataprep-rslex, distro, dotnetcore2, pycparser, cffi, cryptography, PyJWT, idna, urllib3, chardet, requests, msal, portalocker, msal-extensions, azure-core, azure-identity, azureml-dataprep, pyarrow, fusepy, azureml-dataset-runtime, protobuf, typing-extensions, onnx, sklearn-pandas, onnxconverter-common, skl2onnx, isodate, oauthlib, requests-oauthlib, msrest, azure-common, adal, msrestazure, azure-mgmt-resource, jeepney, SecretStorage, azure-mgmt-containerregistry, pyopenssl, websocket-client, docker, backports.weakref, backports.tempfile, azure-mgmt-keyvault, ruamel.yaml.clib, ruamel.yaml, azure-mgmt-storage, pathspec, azure-graphrbac, jmespath, zipp, importlib-metadata, jsonpickle, azure-mgmt-authorization, contextlib2, pyasn1, ndg-httpsclient, azureml-core, patsy, statsmodels, boto, botocore, s3transfer, boto3, smart-open, gensim, lightgbm, termcolor, fire, keras2onnx, onnxmltools, applicationinsights, azureml-telemetry, azureml-automl-core, azureml-train-automl-client, json-logging-py, configparser, liac-arff, dill, azureml-model-management-sdk, gunicorn, werkzeug, MarkupSafe, jinja2, click, itsdangerous, flask, azureml-defaults, packaging, interpret-core, tqdm, shap, interpret-community, azureml-interpret, pmdarima, nimbusml, py-cpuinfo, onnxruntime, azureml-automl-runtime, azure-storage-queue, azureml-train-automl-runtime, wrapt, inference-schema
# Successfully installed MarkupSafe-1.1.1 PyJWT-1.7.1 SecretStorage-3.3.0 adal-1.2.5 applicationinsights-0.11.9 azure-common-1.1.26 azure-core-1.9.0 azure-graphrbac-0.61.1 azure-identity-1.4.1 azure-mgmt-authorization-0.61.0 azure-mgmt-containerregistry-2.8.0 azure-mgmt-keyvault-2.2.0 azure-mgmt-resource-10.3.0 azure-mgmt-storage-11.2.0 azure-storage-queue-12.1.4 azureml-automl-core-1.17.0 azureml-automl-runtime-1.17.0 azureml-core-1.17.0 azureml-dataprep-2.4.4 azureml-dataprep-native-24.0.0 azureml-dataprep-rslex-1.2.3 azureml-dataset-runtime-1.17.0 azureml-defaults-1.17.0 azureml-interpret-1.17.0 azureml-model-management-sdk-1.0.1b6.post1 azureml-telemetry-1.17.0 azureml-train-automl-client-1.17.0 azureml-train-automl-runtime-1.17.0 backports.tempfile-1.0 backports.weakref-1.0.post1 boto-2.49.0 boto3-1.16.25 botocore-1.19.25 cffi-1.14.4 chardet-3.0.4 click-7.1.2 cloudpickle-1.6.0 configparser-3.7.4 contextlib2-0.6.0.post1 cryptography-3.2.1 dill-0.3.3 distro-1.5.0 docker-4.4.0 dotnetcore2-2.1.19 fire-0.3.1 flask-1.0.3 fusepy-3.0.1 gensim-3.8.3 gunicorn-19.9.0 idna-2.10 importlib-metadata-3.1.0 inference-schema-1.1.0 interpret-community-0.15.4 interpret-core-0.2.1 isodate-0.6.0 itsdangerous-1.1.0 jeepney-0.6.0 jinja2-2.11.2 jmespath-0.10.0 json-logging-py-0.2 jsonpickle-1.4.1 keras2onnx-1.6.0 liac-arff-2.5.0 lightgbm-2.3.0 msal-1.6.0 msal-extensions-0.2.2 msrest-0.6.19 msrestazure-0.6.4 ndg-httpsclient-0.5.1 nimbusml-1.8.0 oauthlib-3.1.0 onnx-1.6.0 onnxconverter-common-1.6.0 onnxmltools-1.4.1 onnxruntime-1.3.0 packaging-20.4 pathspec-0.8.1 patsy-0.5.1 pmdarima-1.1.1 portalocker-1.7.1 protobuf-3.14.0 py-cpuinfo-5.0.0 pyarrow-1.0.1 pyasn1-0.4.8 pycparser-2.20 pyopenssl-19.1.0 requests-2.25.0 requests-oauthlib-1.3.0 ruamel.yaml-0.16.12 ruamel.yaml.clib-0.2.2 s3transfer-0.3.3 shap-0.34.0 skl2onnx-1.4.9 sklearn-pandas-1.7.0 smart-open-1.9.0 statsmodels-0.10.2 termcolor-1.1.0 tqdm-4.54.0 typing-extensions-3.7.4.3 urllib3-1.26.2 websocket-client-0.57.0 werkzeug-1.0.1 wrapt-1.11.1 zipp-3.4.0
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.7.12
#   latest version: 4.9.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_28fee3619d571f61730f3ee3b96a407c
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# WARNING: /root/.conda/pkgs does not exist
# Removing intermediate container 8d7f74a46bc5
#  ---> 37feff096a9d
# Step 9/15 : ENV PATH /azureml-envs/azureml_28fee3619d571f61730f3ee3b96a407c/bin:$PATH
#  ---> Running in d50d90bafb60
# Removing intermediate container d50d90bafb60
#  ---> 59687c0800c5
# Step 10/15 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_28fee3619d571f61730f3ee3b96a407c
#  ---> Running in 11e77cce23cf
# Removing intermediate container 11e77cce23cf
#  ---> f26c130e8fa8
# Step 11/15 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_28fee3619d571f61730f3ee3b96a407c/lib:$LD_LIBRARY_PATH
#  ---> Running in c75ddfabdb53
# Removing intermediate container c75ddfabdb53
#  ---> f5e154fb7e34
# Step 12/15 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> 4edeac062ed5
# Step 13/15 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in baf5ae5ff783
# Removing intermediate container baf5ae5ff783
#  ---> 6c639651109d
# Step 14/15 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in 660c57f65737
# Removing intermediate container 660c57f65737
#  ---> 72bacff672fd
# Step 15/15 : CMD ["bash"]
#  ---> Running in d83d19c17b01
# Removing intermediate container d83d19c17b01
#  ---> 3bbda44f1b64
# Successfully built 3bbda44f1b64
# Successfully tagged b4ebf977fa1b4412adb84bc5f3bef665.azurecr.io/azureml/azureml_ff2988e7393ebc1b241bc1c9efecbaba:latest
# 2020/11/27 17:34:54 Successfully executed container: acb_step_0
# 2020/11/27 17:34:54 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2020/11/27 17:34:54 Pushing image: b4ebf977fa1b4412adb84bc5f3bef665.azurecr.io/azureml/azureml_ff2988e7393ebc1b241bc1c9efecbaba:latest, attempt 1
# The push refers to repository [b4ebf977fa1b4412adb84bc5f3bef665.azurecr.io/azureml/azureml_ff2988e7393ebc1b241bc1c9efecbaba]
# 6b322f2aa2d5: Preparing
# eaccc835d087: Preparing
# 2fb068626f88: Preparing
# de9e63d7ce03: Preparing
# 8f9b147ea13e: Preparing
# 9ac87a89c9db: Preparing
# 13e378616f24: Preparing
# efc99d952c3d: Preparing
# 9e292a80b88a: Preparing
# 5e1805eb9eb5: Preparing
# 8dab94e6d05c: Preparing
# 2817caf0a082: Preparing
# aece08fd27fc: Preparing
# 4caea5ef1f0b: Preparing
# dcc0cc99372e: Preparing
# 87c128261339: Preparing
# 41a253a417e6: Preparing
# e06660e80cf4: Preparing
# 8dab94e6d05c: Waiting
# 2817caf0a082: Waiting
# aece08fd27fc: Waiting
# 4caea5ef1f0b: Waiting
# dcc0cc99372e: Waiting
# 87c128261339: Waiting
# 41a253a417e6: Waiting
# e06660e80cf4: Waiting
# 13e378616f24: Waiting
# efc99d952c3d: Waiting
# 9e292a80b88a: Waiting
# 5e1805eb9eb5: Waiting
# 9ac87a89c9db: Waiting
# 2fb068626f88: Pushed
# 6b322f2aa2d5: Pushed
# 8f9b147ea13e: Pushed
# 13e378616f24: Pushed
# 9ac87a89c9db: Pushed
# de9e63d7ce03: Pushed
# efc99d952c3d: Pushed
# 9e292a80b88a: Pushed
# aece08fd27fc: Pushed
# 2817caf0a082: Pushed
# dcc0cc99372e: Pushed
# 8dab94e6d05c: Pushed
# 5e1805eb9eb5: Pushed
# 87c128261339: Pushed
# 41a253a417e6: Pushed
# 4caea5ef1f0b: Pushed
#
# e06660e80cf4: Pushed
#
# eaccc835d087: Pushed
# latest: digest: sha256:e8b1dde94802c387f3e7d6422bc442f002959c6a26a8bf58f4cc7d29f834af14 size: 4096
# 2020/11/27 17:39:38 Successfully pushed image: b4ebf977fa1b4412adb84bc5f3bef665.azurecr.io/azureml/azureml_ff2988e7393ebc1b241bc1c9efecbaba:latest
# 2020/11/27 17:39:38 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 459.499871)
# 2020/11/27 17:39:38 Populating digests for step ID: acb_step_0...
# 2020/11/27 17:39:39 Successfully populated digests for step ID: acb_step_0
# 2020/11/27 17:39:39 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 283.479980)
# 2020/11/27 17:39:39 The following dependencies were found:
# 2020/11/27 17:39:39
# - image:
#     registry: b4ebf977fa1b4412adb84bc5f3bef665.azurecr.io
#     repository: azureml/azureml_ff2988e7393ebc1b241bc1c9efecbaba
#     tag: latest
#     digest: sha256:e8b1dde94802c387f3e7d6422bc442f002959c6a26a8bf58f4cc7d29f834af14
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/intelmpi2018.3-ubuntu16.04
#     tag: 20200821.v1
#     digest: sha256:8cee6f674276dddb23068d2710da7f7f95b119412cc482675ac79ba45a4acf99
#   git: {}
#
#
# Run ID: cd1 was successful after 12m31s
# 2020/11/27 17:40:18 Downloading source code...
# 2020/11/27 17:40:19 Finished downloading source code
# 2020/11/27 17:40:20 Creating Docker network: acb_default_network, driver: 'bridge'
# 2020/11/27 17:40:20 Successfully set up Docker network: acb_default_network
# 2020/11/27 17:40:20 Setting up Docker configuration...
# 2020/11/27 17:40:21 Successfully set up Docker configuration
# 2020/11/27 17:40:21 Logging in to registry: b4ebf977fa1b4412adb84bc5f3bef665.azurecr.io
# 2020/11/27 17:40:22 Successfully logged into b4ebf977fa1b4412adb84bc5f3bef665.azurecr.io
# 2020/11/27 17:40:22 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2020/11/27 17:40:22 Launching container with name: acb_step_0
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /acb/home/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded
# 2020/11/27 17:40:24 Successfully executed container: acb_step_0
# 2020/11/27 17:40:24 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2020/11/27 17:40:24 Scanning for dependencies...
# 2020/11/27 17:40:24 Successfully scanned dependencies
# 2020/11/27 17:40:24 Launching container with name: acb_step_1
# Sending build context to Docker daemon  65.02kB
# Step 1/8 : FROM b4ebf977fa1b4412adb84bc5f3bef665.azurecr.io/azureml/azureml_ff2988e7393ebc1b241bc1c9efecbaba
# latest: Pulling from azureml/azureml_ff2988e7393ebc1b241bc1c9efecbaba
# 8e097b52bfb8: Already exists
# a613a9b4553c: Already exists
# acc000f01536: Already exists
# 73eef93b7466: Already exists
# d5a54c1fb97f: Already exists
# 1536f6ca931b: Already exists
# d7b631d130cb: Already exists
# 75ffe8dfb222: Already exists
# 86b4bf2f8d5f: Already exists
# 5335952fa8d3: Already exists
# 96fa3cc6fe10: Already exists
# e428dd9daa94: Already exists
# ae7b523c9057: Pulling fs layer
# f1600310eb2b: Pulling fs layer
# 347360a90977: Pulling fs layer
# 48a8d6471d67: Pulling fs layer
# 02c9b478a9ee: Pulling fs layer
# 67bcbf4ea0da: Pulling fs layer
# 48a8d6471d67: Waiting
# 02c9b478a9ee: Waiting
# 67bcbf4ea0da: Waiting
# ae7b523c9057: Verifying Checksum
# ae7b523c9057: Download complete
# f1600310eb2b: Verifying Checksum
# f1600310eb2b: Download complete
# 347360a90977: Download complete
# 67bcbf4ea0da: Verifying Checksum
# 67bcbf4ea0da: Download complete
# ae7b523c9057: Pull complete
# f1600310eb2b: Pull complete
# 347360a90977: Pull complete
# 48a8d6471d67: Verifying Checksum
# 48a8d6471d67: Download complete
# 48a8d6471d67: Pull complete
# 02c9b478a9ee: Verifying Checksum
# 02c9b478a9ee: Download complete
# 02c9b478a9ee: Pull complete
# 67bcbf4ea0da: Pull complete
# Digest: sha256:e8b1dde94802c387f3e7d6422bc442f002959c6a26a8bf58f4cc7d29f834af14
# Status: Downloaded newer image for b4ebf977fa1b4412adb84bc5f3bef665.azurecr.io/azureml/azureml_ff2988e7393ebc1b241bc1c9efecbaba:latest
#  ---> 3bbda44f1b64
# Step 2/8 : ENV AZUREML_MODEL_DIR=azureml-models/deployments-bankmarketing/1
#  ---> Running in d10f8eac6cb9
# Removing intermediate container d10f8eac6cb9
#  ---> 57edaaf0517e
# Step 3/8 : RUN mkdir -p '/var/azureml-app' && /var/azureml-util/download_asset.sh 'https://mlstrg128108.blob.core.windows.net/azureml/LocalUpload/8bb6ba30/tmpolys2yco.py?sv=2019-02-02&sr=b&sig=isaIkf9dxzzaphfiolzqkVFE2Ol7C4mkjyCkNl2nr8U%3D&st=2020-11-27T17%3A30%3A15Z&se=2020-11-28T01%3A40%3A15Z&sp=r' '/var/azureml-app/tmpolys2yco.py'
#  ---> Running in e050cc8cc3ab
# Downloading https://mlstrg128108.blob.core.windows.net/azureml/LocalUpload/8bb6ba30/tmpolys2yco.py?sv=2019-02-02&sr=b&sig=isaIkf9dxzzaphfiolzqkVFE2Ol7C4mkjyCkNl2nr8U%3D&st=2020-11-27T17%3A30%3A15Z&se=2020-11-28T01%3A40%3A15Z&sp=r as /var/azureml-app/tmpolys2yco.py
# wget: /azureml-envs/azureml_28fee3619d571f61730f3ee3b96a407c/lib/libcrypto.so.1.0.0: no version information available (required by wget)
# wget: /azureml-envs/azureml_28fee3619d571f61730f3ee3b96a407c/lib/libuuid.so.1: no version information available (required by wget)
# wget: /azureml-envs/azureml_28fee3619d571f61730f3ee3b96a407c/lib/libssl.so.1.0.0: no version information available (required by wget)
# wget: /azureml-envs/azureml_28fee3619d571f61730f3ee3b96a407c/lib/libssl.so.1.0.0: no version information available (required by wget)
# --2020-11-27 17:42:03--  https://mlstrg128108.blob.core.windows.net/azureml/LocalUpload/8bb6ba30/tmpolys2yco.py?sv=2019-02-02&sr=b&sig=isaIkf9dxzzaphfiolzqkVFE2Ol7C4mkjyCkNl2nr8U%3D&st=2020-11-27T17%3A30%3A15Z&se=2020-11-28T01%3A40%3A15Z&sp=r
# Resolving mlstrg128108.blob.core.windows.net (mlstrg128108.blob.core.windows.net)... 20.150.38.196
# Connecting to mlstrg128108.blob.core.windows.net (mlstrg128108.blob.core.windows.net)|20.150.38.196|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1079 (1.1K) [application/octet-stream]
# Saving to: ‘/var/azureml-app/tmpolys2yco.py’
#
#      0K                                    100%  116M=0s
#
# 2020-11-27 17:42:03 (116 MB/s) - ‘/var/azureml-app/tmpolys2yco.py’ saved [1079/1079]
#
# Removing intermediate container e050cc8cc3ab
#  ---> 903f54bf3631
# Step 4/8 : RUN mkdir -p '/var/azureml-app' && /var/azureml-util/download_asset.sh 'https://mlstrg128108.blob.core.windows.net/azureml/LocalUpload/4aedf154/scoring_file_v_1_0_0.py?sv=2019-02-02&sr=b&sig=hBar6%2BPT%2BtD7MQe%2BXHirhTW5JiALzP0EdQE7vfEIpvc%3D&st=2020-11-27T17%3A30%3A15Z&se=2020-11-28T01%3A40%3A15Z&sp=r' '/var/azureml-app/scoring_file_v_1_0_0.py'
#  ---> Running in 871b31b86c40
# Downloading https://mlstrg128108.blob.core.windows.net/azureml/LocalUpload/4aedf154/scoring_file_v_1_0_0.py?sv=2019-02-02&sr=b&sig=hBar6%2BPT%2BtD7MQe%2BXHirhTW5JiALzP0EdQE7vfEIpvc%3D&st=2020-11-27T17%3A30%3A15Z&se=2020-11-28T01%3A40%3A15Z&sp=r as /var/azureml-app/scoring_file_v_1_0_0.py
# wget: /azureml-envs/azureml_28fee3619d571f61730f3ee3b96a407c/lib/libcrypto.so.1.0.0: no version information available (required by wget)
# wget: /azureml-envs/azureml_28fee3619d571f61730f3ee3b96a407c/lib/libuuid.so.1: no version information available (required by wget)
# wget: /azureml-envs/azureml_28fee3619d571f61730f3ee3b96a407c/lib/libssl.so.1.0.0: no version information available (required by wget)
# wget: /azureml-envs/azureml_28fee3619d571f61730f3ee3b96a407c/lib/libssl.so.1.0.0: no version information available (required by wget)
# --2020-11-27 17:42:08--  https://mlstrg128108.blob.core.windows.net/azureml/LocalUpload/4aedf154/scoring_file_v_1_0_0.py?sv=2019-02-02&sr=b&sig=hBar6%2BPT%2BtD7MQe%2BXHirhTW5JiALzP0EdQE7vfEIpvc%3D&st=2020-11-27T17%3A30%3A15Z&se=2020-11-28T01%3A40%3A15Z&sp=r
# Resolving mlstrg128108.blob.core.windows.net (mlstrg128108.blob.core.windows.net)... 20.150.38.196
# Connecting to mlstrg128108.blob.core.windows.net (mlstrg128108.blob.core.windows.net)|20.150.38.196|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2811 (2.7K) [application/octet-stream]
# Saving to: ‘/var/azureml-app/scoring_file_v_1_0_0.py’
#
#      0K                                    100%  274M=0s
#
# 2020-11-27 17:42:09 (274 MB/s) - ‘/var/azureml-app/scoring_file_v_1_0_0.py’ saved [2811/2811]
#
# Removing intermediate container 871b31b86c40
#  ---> c2a4cf5f397c
# Step 5/8 : RUN mkdir -p '/var/azureml-app/azureml-models/deployments-bankmarketing/1' && /var/azureml-util/download_asset.sh 'https://mlstrg128108.blob.core.windows.net/azureml/ExperimentRun/dcid.AutoML_e28797ba-b58f-40d7-ade4-691014ee52eb_44/outputs/model.pkl?sv=2019-02-02&sr=b&sig=iNyfUeFiFhs0qYmo4iNJGES0gJo%2BlUuESFiYdcxQ%2BEA%3D&st=2020-11-27T17%3A30%3A14Z&se=2020-11-28T01%3A40%3A14Z&sp=r' '/var/azureml-app/azureml-models/deployments-bankmarketing/1/model.pkl'
#  ---> Running in bf89b1871a27
# Downloading https://mlstrg128108.blob.core.windows.net/azureml/ExperimentRun/dcid.AutoML_e28797ba-b58f-40d7-ade4-691014ee52eb_44/outputs/model.pkl?sv=2019-02-02&sr=b&sig=iNyfUeFiFhs0qYmo4iNJGES0gJo%2BlUuESFiYdcxQ%2BEA%3D&st=2020-11-27T17%3A30%3A14Z&se=2020-11-28T01%3A40%3A14Z&sp=r as /var/azureml-app/azureml-models/deployments-bankmarketing/1/model.pkl
# wget: /azureml-envs/azureml_28fee3619d571f61730f3ee3b96a407c/lib/libcrypto.so.1.0.0: no version information available (required by wget)
# wget: /azureml-envs/azureml_28fee3619d571f61730f3ee3b96a407c/lib/libuuid.so.1: no version information available (required by wget)
# wget: /azureml-envs/azureml_28fee3619d571f61730f3ee3b96a407c/lib/libssl.so.1.0.0: no version information available (required by wget)
# wget: /azureml-envs/azureml_28fee3619d571f61730f3ee3b96a407c/lib/libssl.so.1.0.0: no version information available (required by wget)
# --2020-11-27 17:42:14--  https://mlstrg128108.blob.core.windows.net/azureml/ExperimentRun/dcid.AutoML_e28797ba-b58f-40d7-ade4-691014ee52eb_44/outputs/model.pkl?sv=2019-02-02&sr=b&sig=iNyfUeFiFhs0qYmo4iNJGES0gJo%2BlUuESFiYdcxQ%2BEA%3D&st=2020-11-27T17%3A30%3A14Z&se=2020-11-28T01%3A40%3A14Z&sp=r
# Resolving mlstrg128108.blob.core.windows.net (mlstrg128108.blob.core.windows.net)... 20.150.38.196
# Connecting to mlstrg128108.blob.core.windows.net (mlstrg128108.blob.core.windows.net)|20.150.38.196|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1994995 (1.9M) [application/octet-stream]
# Saving to: ‘/var/azureml-app/azureml-models/deployments-bankmarketing/1/model.pkl’
#
#      0K .                                  100% 66.5M=0.03s
#
# 2020-11-27 17:42:15 (66.5 MB/s) - ‘/var/azureml-app/azureml-models/deployments-bankmarketing/1/model.pkl’ saved [1994995/1994995]
#
# Removing intermediate container bf89b1871a27
#  ---> be20d054eb6f
# Step 6/8 : RUN mkdir -p '/var/azureml-app' && echo ... | base64 --decode > /var/azureml-app/model_config_map.json
#  ---> Running in 6c1965c368a7
# Removing intermediate container 6c1965c368a7
#  ---> 7570c82ec366
# Step 7/8 : RUN mv '/var/azureml-app/tmpolys2yco.py' /var/azureml-app/main.py
#  ---> Running in 3da0377869d1
# Removing intermediate container 3da0377869d1
#  ---> ae61563a1ee0
# Step 8/8 : CMD ["runsvdir","/var/runit"]
#  ---> Running in ae4835aeb776
# Removing intermediate container ae4835aeb776
#  ---> f7eec949b087
# Successfully built f7eec949b087
# Successfully tagged b4ebf977fa1b4412adb84bc5f3bef665.azurecr.io/azureml/azureml_b5301a2b92a67e644c297d486f25b756:latest
# 2020/11/27 17:42:37 Successfully executed container: acb_step_1
# 2020/11/27 17:42:37 Executing step ID: acb_step_2. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2020/11/27 17:42:37 Pushing image: b4ebf977fa1b4412adb84bc5f3bef665.azurecr.io/azureml/azureml_b5301a2b92a67e644c297d486f25b756:latest, attempt 1
# The push refers to repository [b4ebf977fa1b4412adb84bc5f3bef665.azurecr.io/azureml/azureml_b5301a2b92a67e644c297d486f25b756]
# 79b3ec027d62: Preparing
# 9e8060c8ffbb: Preparing
# d4470e6e2e57: Preparing
# 7100605fad0f: Preparing
# 11af6f4bb34d: Preparing
# 6b322f2aa2d5: Preparing
# eaccc835d087: Preparing
# 2fb068626f88: Preparing
# de9e63d7ce03: Preparing
# 8f9b147ea13e: Preparing
# 9ac87a89c9db: Preparing
# 13e378616f24: Preparing
# efc99d952c3d: Preparing
# 9e292a80b88a: Preparing
# 5e1805eb9eb5: Preparing
# 8dab94e6d05c: Preparing
# 2817caf0a082: Preparing
# aece08fd27fc: Preparing
# 4caea5ef1f0b: Preparing
# dcc0cc99372e: Preparing
# 87c128261339: Preparing
# 41a253a417e6: Preparing
# e06660e80cf4: Preparing
# 6b322f2aa2d5: Waiting
# eaccc835d087: Waiting
# 2fb068626f88: Waiting
# de9e63d7ce03: Waiting
# 8f9b147ea13e: Waiting
# 9ac87a89c9db: Waiting
# 13e378616f24: Waiting
# efc99d952c3d: Waiting
# 9e292a80b88a: Waiting
# 5e1805eb9eb5: Waiting
# 8dab94e6d05c: Waiting
# 2817caf0a082: Waiting
# aece08fd27fc: Waiting
# 4caea5ef1f0b: Waiting
# dcc0cc99372e: Waiting
# 87c128261339: Waiting
# 41a253a417e6: Waiting
# e06660e80cf4: Waiting
# 11af6f4bb34d: Pushed
# 9e8060c8ffbb: Pushed
# 79b3ec027d62: Pushed
# 7100605fad0f: Pushed
# d4470e6e2e57: Pushed
# 6b322f2aa2d5: Mounted from azureml/azureml_ff2988e7393ebc1b241bc1c9efecbaba
# eaccc835d087: Mounted from azureml/azureml_ff2988e7393ebc1b241bc1c9efecbaba
# de9e63d7ce03: Mounted from azureml/azureml_ff2988e7393ebc1b241bc1c9efecbaba
# 8f9b147ea13e: Mounted from azureml/azureml_ff2988e7393ebc1b241bc1c9efecbaba
# 2fb068626f88: Mounted from azureml/azureml_ff2988e7393ebc1b241bc1c9efecbaba
# 13e378616f24: Mounted from azureml/azureml_ff2988e7393ebc1b241bc1c9efecbaba
# 9ac87a89c9db: Mounted from azureml/azureml_ff2988e7393ebc1b241bc1c9efecbaba
# efc99d952c3d: Mounted from azureml/azureml_ff2988e7393ebc1b241bc1c9efecbaba
# 9e292a80b88a: Mounted from azureml/azureml_ff2988e7393ebc1b241bc1c9efecbaba
# 5e1805eb9eb5: Mounted from azureml/azureml_ff2988e7393ebc1b241bc1c9efecbaba
# 8dab94e6d05c: Mounted from azureml/azureml_ff2988e7393ebc1b241bc1c9efecbaba
# 2817caf0a082: Mounted from azureml/azureml_ff2988e7393ebc1b241bc1c9efecbaba
# aece08fd27fc: Mounted from azureml/azureml_ff2988e7393ebc1b241bc1c9efecbaba
# dcc0cc99372e: Mounted from azureml/azureml_ff2988e7393ebc1b241bc1c9efecbaba
# 4caea5ef1f0b: Mounted from azureml/azureml_ff2988e7393ebc1b241bc1c9efecbaba
# 87c128261339: Mounted from azureml/azureml_ff2988e7393ebc1b241bc1c9efecbaba
# 41a253a417e6: Mounted from azureml/azureml_ff2988e7393ebc1b241bc1c9efecbaba
# e06660e80cf4: Mounted from azureml/azureml_ff2988e7393ebc1b241bc1c9efecbaba
# latest: digest: sha256:e57931917c5f05c619c3d0bbd1af1fd55c63e749f9a9f95d94eae2310e4b1114 size: 5135
# 2020/11/27 17:43:01 Successfully pushed image: b4ebf977fa1b4412adb84bc5f3bef665.azurecr.io/azureml/azureml_b5301a2b92a67e644c297d486f25b756:latest
# 2020/11/27 17:43:01 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 1.201398)
# 2020/11/27 17:43:01 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 133.113479)
# 2020/11/27 17:43:01 Populating digests for step ID: acb_step_1...
# 2020/11/27 17:43:03 Successfully populated digests for step ID: acb_step_1
# 2020/11/27 17:43:03 Step ID: acb_step_2 marked as successful (elapsed time in seconds: 24.475318)
# 2020/11/27 17:43:03 The following dependencies were found:
# 2020/11/27 17:43:03
# - image:
#     registry: b4ebf977fa1b4412adb84bc5f3bef665.azurecr.io
#     repository: azureml/azureml_b5301a2b92a67e644c297d486f25b756
#     tag: latest
#     digest: sha256:e57931917c5f05c619c3d0bbd1af1fd55c63e749f9a9f95d94eae2310e4b1114
#   runtime-dependency:
#     registry: b4ebf977fa1b4412adb84bc5f3bef665.azurecr.io
#     repository: azureml/azureml_ff2988e7393ebc1b241bc1c9efecbaba
#     tag: latest
#     digest: sha256:e8b1dde94802c387f3e7d6422bc442f002959c6a26a8bf58f4cc7d29f834af14
#   git: {}
#
# Run ID: cd2 was successful after 2m46s
# Package creation Succeeded
# Pulling image from ACR (this may take a few minutes depending on image size)...
#
# sha256:e57931917c5f05c619c3d0bbd1af1fd55c63e749f9a9f95d94eae2310e4b1114: Pulling from package
# 8e097b52bfb8: Pulling fs layer
# a613a9b4553c: Pulling fs layer
# acc000f01536: Pulling fs layer
# 73eef93b7466: Pulling fs layer
# d5a54c1fb97f: Pulling fs layer
# 1536f6ca931b: Pulling fs layer
# d7b631d130cb: Pulling fs layer
# 75ffe8dfb222: Pulling fs layer
# 86b4bf2f8d5f: Pulling fs layer
# ...
# 86b4bf2f8d5f: Downloading
# 75ffe8dfb222: Verifying Checksum
# 75ffe8dfb222: Download complete
# 8e097b52bfb8: Extracting
# 86b4bf2f8d5f: Downloading
# d5a54c1fb97f: Downloading
# 8e097b52bfb8: Extracting
# 5335952fa8d3: Downloading
# 86b4bf2f8d5f: Downloading
# 8e097b52bfb8: Extracting
# d5a54c1fb97f: Downloading
# 86b4bf2f8d5f: Verifying Checksum
# 86b4bf2f8d5f: Download complete
# 8e097b52bfb8: Extracting
# 96fa3cc6fe10: Downloading
# 96fa3cc6fe10: Verifying Checksum
# 96fa3cc6fe10: Download complete
# e428dd9daa94: Downloading
# e428dd9daa94: Downloading
# e428dd9daa94: Verifying Checksum
# e428dd9daa94: Download complete
# 8e097b52bfb8: Extracting
# ae7b523c9057: Downloading
# ae7b523c9057: Verifying Checksum
# ae7b523c9057: Download complete
# 8e097b52bfb8: Extracting
# f1600310eb2b: Download complete
# 5335952fa8d3: Downloading
# 347360a90977: Downloading
# 347360a90977: Downloading
# 347360a90977: Verifying Checksum
# 347360a90977: Download complete
# d5a54c1fb97f: Downloading
# 5335952fa8d3: Verifying Checksum
# 5335952fa8d3: Download complete
# 8e097b52bfb8: Pull complete
# a613a9b4553c: Extracting
# a613a9b4553c: Extracting
# 48a8d6471d67: Downloading
# 48a8d6471d67: Verifying Checksum
# 48a8d6471d67: Download complete
# d5a54c1fb97f: Downloading
# 67bcbf4ea0da: Downloading
# 67bcbf4ea0da: Verifying Checksum
# 67bcbf4ea0da: Download complete
# a613a9b4553c: Pull complete
# acc000f01536: Extracting
# acc000f01536: Extracting
# 4b346aad5333: Downloading
# 4b346aad5333: Verifying Checksum
# 4b346aad5333: Download complete
# 02c9b478a9ee: Downloading
# acc000f01536: Pull complete
# 73eef93b7466: Extracting
# 73eef93b7466: Extracting
# 02c9b478a9ee: Downloading
# d5a54c1fb97f: Downloading
# 73eef93b7466: Pull complete
# 366eeeaafcf0: Downloading
# 366eeeaafcf0: Verifying Checksum
# 366eeeaafcf0: Download complete
# 02c9b478a9ee: Downloading
# 4657a8c446df: Downloading
# 4657a8c446df: Verifying Checksum
# 4657a8c446df: Download complete
# d5a54c1fb97f: Downloading
# 02c9b478a9ee: Downloading
# 8b20105522c0: Downloading
# 8b20105522c0: Verifying Checksum
# 8b20105522c0: Download complete
# cc42268092bc: Downloading
# cc42268092bc: Verifying Checksum
# cc42268092bc: Download complete
# 02c9b478a9ee: Downloading
# d5a54c1fb97f: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# d5a54c1fb97f: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# d5a54c1fb97f: Downloading
# 02c9b478a9ee: Downloading
# d5a54c1fb97f: Downloading
# 02c9b478a9ee: Downloading
# d5a54c1fb97f: Downloading
# d5a54c1fb97f: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# d5a54c1fb97f: Downloading
# 02c9b478a9ee: Downloading
# d5a54c1fb97f: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# d5a54c1fb97f: Downloading
# d5a54c1fb97f: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# d5a54c1fb97f: Downloading
# 02c9b478a9ee: Downloading
# d5a54c1fb97f: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# d5a54c1fb97f: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# d5a54c1fb97f: Downloading
# d5a54c1fb97f: Downloading
# 02c9b478a9ee: Downloading
# d5a54c1fb97f: Downloading
# 02c9b478a9ee: Downloading
# d5a54c1fb97f: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# d5a54c1fb97f: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# d5a54c1fb97f: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# d5a54c1fb97f: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# d5a54c1fb97f: Downloading
# 02c9b478a9ee: Downloading
# d5a54c1fb97f: Downloading
# d5a54c1fb97f: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# d5a54c1fb97f: Downloading
# 02c9b478a9ee: Downloading
# d5a54c1fb97f: Downloading
# 02c9b478a9ee: Downloading
# d5a54c1fb97f: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# d5a54c1fb97f: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# d5a54c1fb97f: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# d5a54c1fb97f: Downloading
# 02c9b478a9ee: Downloading
# d5a54c1fb97f: Downloading
# 02c9b478a9ee: Downloading
# d5a54c1fb97f: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# d5a54c1fb97f: Downloading
# d5a54c1fb97f: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# d5a54c1fb97f: Downloading
# d5a54c1fb97f: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# d5a54c1fb97f: Downloading
# 02c9b478a9ee: Downloading
# d5a54c1fb97f: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# d5a54c1fb97f: Downloading
# d5a54c1fb97f: Downloading
# 02c9b478a9ee: Downloading
# d5a54c1fb97f: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# d5a54c1fb97f: Downloading
# 02c9b478a9ee: Downloading
# d5a54c1fb97f: Verifying Checksum
# d5a54c1fb97f: Download complete
# d5a54c1fb97f: Extracting
# 02c9b478a9ee: Downloading
# d5a54c1fb97f: Extracting
# d5a54c1fb97f: Extracting
# 02c9b478a9ee: Downloading
# d5a54c1fb97f: Extracting
# 02c9b478a9ee: Downloading
# d5a54c1fb97f: Extracting
# 02c9b478a9ee: Downloading
# d5a54c1fb97f: Extracting
# 02c9b478a9ee: Downloading
# d5a54c1fb97f: Extracting
# 02c9b478a9ee: Downloading
# d5a54c1fb97f: Extracting
# d5a54c1fb97f: Extracting
# d5a54c1fb97f: Extracting
# d5a54c1fb97f: Extracting
# 02c9b478a9ee: Downloading
# d5a54c1fb97f: Extracting
# 02c9b478a9ee: Downloading
# d5a54c1fb97f: Extracting
# 02c9b478a9ee: Downloading
# d5a54c1fb97f: Extracting
# 02c9b478a9ee: Downloading
# d5a54c1fb97f: Extracting
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# d5a54c1fb97f: Extracting
# d5a54c1fb97f: Extracting
# d5a54c1fb97f: Extracting
# d5a54c1fb97f: Extracting
# 02c9b478a9ee: Downloading
# d5a54c1fb97f: Extracting
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# d5a54c1fb97f: Extracting
# d5a54c1fb97f: Extracting
# d5a54c1fb97f: Extracting
# d5a54c1fb97f: Extracting
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# d5a54c1fb97f: Pull complete
# 02c9b478a9ee: Downloading
# 1536f6ca931b: Extracting
# 02c9b478a9ee: Downloading
# 1536f6ca931b: Extracting
# 1536f6ca931b: Extracting
# 1536f6ca931b: Extracting
# 02c9b478a9ee: Downloading
# 1536f6ca931b: Extracting
# 02c9b478a9ee: Downloading
# 1536f6ca931b: Extracting
# 1536f6ca931b: Extracting
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Downloading
# 02c9b478a9ee: Verifying Checksum
# 02c9b478a9ee: Download complete
# 1536f6ca931b: Pull complete
# d7b631d130cb: Extracting
# d7b631d130cb: Extracting
# d7b631d130cb: Extracting
# d7b631d130cb: Extracting
# d7b631d130cb: Extracting
# d7b631d130cb: Extracting
# d7b631d130cb: Extracting
# d7b631d130cb: Extracting
# d7b631d130cb: Extracting
# d7b631d130cb: Extracting
# d7b631d130cb: Pull complete
# 75ffe8dfb222: Extracting
# 75ffe8dfb222: Extracting
# 75ffe8dfb222: Extracting
# 75ffe8dfb222: Extracting
# 75ffe8dfb222: Extracting
# 75ffe8dfb222: Extracting
# 75ffe8dfb222: Extracting
# 75ffe8dfb222: Extracting
# 75ffe8dfb222: Extracting
# 75ffe8dfb222: Extracting
# 75ffe8dfb222: Extracting
# 75ffe8dfb222: Extracting
# 75ffe8dfb222: Extracting
# 75ffe8dfb222: Extracting
# 75ffe8dfb222: Extracting
# 75ffe8dfb222: Pull complete
# 86b4bf2f8d5f: Extracting
# 86b4bf2f8d5f: Extracting
# 86b4bf2f8d5f: Extracting
# 86b4bf2f8d5f: Extracting
# 86b4bf2f8d5f: Extracting
# 86b4bf2f8d5f: Extracting
# 86b4bf2f8d5f: Extracting
# 86b4bf2f8d5f: Extracting
# 86b4bf2f8d5f: Extracting
# 86b4bf2f8d5f: Extracting
# 86b4bf2f8d5f: Extracting
# 86b4bf2f8d5f: Extracting
# 86b4bf2f8d5f: Extracting
# 86b4bf2f8d5f: Extracting
# 86b4bf2f8d5f: Extracting
# 86b4bf2f8d5f: Extracting
# 86b4bf2f8d5f: Extracting
# 86b4bf2f8d5f: Extracting
# 86b4bf2f8d5f: Extracting
# 86b4bf2f8d5f: Pull complete
# 5335952fa8d3: Extracting
# 5335952fa8d3: Extracting
# 5335952fa8d3: Extracting
# 5335952fa8d3: Extracting
# 5335952fa8d3: Extracting
# 5335952fa8d3: Pull complete
# 96fa3cc6fe10: Extracting
# 96fa3cc6fe10: Extracting
# 96fa3cc6fe10: Pull complete
# e428dd9daa94: Extracting
# e428dd9daa94: Extracting
# e428dd9daa94: Extracting
# e428dd9daa94: Pull complete
# ae7b523c9057: Extracting
# ae7b523c9057: Extracting
# ae7b523c9057: Pull complete
# f1600310eb2b: Extracting
# f1600310eb2b: Extracting
# f1600310eb2b: Pull complete
# 347360a90977: Extracting
# 347360a90977: Extracting
# 347360a90977: Extracting
# 347360a90977: Pull complete
# 48a8d6471d67: Extracting
# 48a8d6471d67: Extracting
# 48a8d6471d67: Pull complete
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Extracting
# 02c9b478a9ee: Pull complete
# 67bcbf4ea0da: Extracting
# 67bcbf4ea0da: Extracting
# 67bcbf4ea0da: Pull complete
# 4b346aad5333: Extracting
# 4b346aad5333: Extracting
# 4b346aad5333: Pull complete
# 366eeeaafcf0: Extracting
# 366eeeaafcf0: Extracting
# 366eeeaafcf0: Pull complete
# 4657a8c446df: Extracting
# 4657a8c446df: Extracting
# 4657a8c446df: Pull complete
# 8b20105522c0: Extracting
# 8b20105522c0: Extracting
# 8b20105522c0: Pull complete
# cc42268092bc: Extracting
# cc42268092bc: Extracting
# cc42268092bc: Pull complete
# Digest: sha256:e57931917c5f05c619c3d0bbd1af1fd55c63e749f9a9f95d94eae2310e4b1114
# Status: Downloaded newer image for b4ebf977fa1b4412adb84bc5f3bef665.azurecr.io/package@sha256:e57931917c5f05c619c3d0bbd1af1fd55c63e749f9a9f95d94eae2310e4b1114

# %% [markdown]
# The above cell should produce a result such as:
#
# Downloaded newer image for myworkspacef78fd10.azurecr.io/package:20190822181338.
#
# In git-bash run:
#
# "docker images"
#
# "docker run -p 6789:5001 --name mycontainer imageID" (replace id number)
#
# After the container is started, submit requests to http://localhost:6789/score

# %%
# Test the container   
 
# Prepare 5 example data for Docker
examples = examples.take(5).to_pandas_dataframe()
data_docker = {"data":examples.to_json(orient='records')}                                         

# URL for the web service.
scoring_uri = 'http://localhost:6789/score'

# Convert data to JSON string.
input_data = json.dumps(data_docker)

# Set the content type.
headers = {'Content-Type': 'application/json'}

# Make the request and display the response.
resp = requests.post(scoring_uri, input_data, headers=headers)
print(resp.text)

# %% [markdown]
# ### TO DOWNLAD FILES TO BUILD A LOCAL IMAGE

# %%
# Package with the dockerfile rather than the image
package = model.package(ws, [], inference_config, generate_dockerfile=True)
package.wait_for_creation(show_output=True)
# Download the package.
package.save("./imagefiles")
# Get the Azure container registry that the model/Dockerfile uses.
acr=package.get_container_registry()
print("Address:", acr.address)
print("Username:", acr.username)
print("Password:", acr.password)
# Out:
# Package creation Succeeded
# Logging into Docker registry b4ebf977fa1b4412adb84bc5f3bef665.azurecr.io
# Address: b4ebf977fa1b4412adb84bc5f3bef665.azurecr.io
# Username: b4ebf977fa1b4412adb84bc5f3bef665
# Password: X0ED=y8qbqAqTxj377tDw5ZQPoYNwSRd

# %% [markdown]
# In git-bash run:
#
# "docker login (address) -u (username) -p (password)"
#
# "docker build --tag myimage imagefiles" (replace imagefiles with the path were the image was saved)
#
# "docker image"
#
# "docker run -p 6789:5001 --name mycontainer myimage:latest"
#
# When finished run:
#
# "docker kill mycontainer"

# %% [markdown]
# # BATCH SCORING

# %%
# Get default datastore
datastore = ws.get_default_datastore()
# output
output_dir = PipelineData(name="scores", datastore=datastore, output_path_on_compute="./results")
# environment
env = Environment(name="deployments")     
# Prepare data for batch inference
examples_batch = examples.as_named_input("examples_batch")

# %%
# Parallel run configuration
parallel_run_config = ParallelRunConfig(source_directory='.',
                                        entry_script='batch_inference.py', 
                                        environment=env,
                                        error_threshold=5,
                                        output_action='append_row',
                                        append_row_file_name="batch_inference.txt",
                                        compute_target=compute_target, 
                                        node_count=1)

# %%
# Batch scoring step    
batch_score_step = ParallelRunStep(name="batch-scoring",
                                    inputs=[examples_batch],                            
                                    output=output_dir,
                                    arguments=["--model_name", 'deployments-bankmarketing'],  
                                    parallel_run_config=parallel_run_config,
                                    allow_reuse=True)

# %%
# Submit the pipeline
pipeline = Pipeline(workspace=ws, steps=[batch_score_step])
batch_run = experiment.submit(pipeline)
batch_run.wait_for_completion(show_output=True)
# Out:
# Created step batch-scoring [f6835d3c][b4c6cd85-fe13-4275-9b97-bc10302cf870], (This step will run and generate new outputs)
# Submitted PipelineRun 9aa84471-ec5c-43a0-a49e-2306a9946b62
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/deployments-bankmarketing/runs/9aa84471-ec5c-43a0-a49e-2306a9946b62?wsid=/subscriptions/dafd62fe-51d3-4671-af50-6bac2f001b5d/resourcegroups/aml-quickstarts-128108/workspaces/quick-starts-ws-128108
# PipelineRunId: 9aa84471-ec5c-43a0-a49e-2306a9946b62
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/deployments-bankmarketing/runs/9aa84471-ec5c-43a0-a49e-2306a9946b62?wsid=/subscriptions/dafd62fe-51d3-4671-af50-6bac2f001b5d/resourcegroups/aml-quickstarts-128108/workspaces/quick-starts-ws-128108
# PipelineRun Status: Running
#
#
# StepRunId: a0e18dd2-c478-419a-965b-a918d577f270
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/deployments-bankmarketing/runs/a0e18dd2-c478-419a-965b-a918d577f270?wsid=/subscriptions/dafd62fe-51d3-4671-af50-6bac2f001b5d/resourcegroups/aml-quickstarts-128108/workspaces/quick-starts-ws-128108
# StepRun( batch-scoring ) Status: NotStarted
# StepRun( batch-scoring ) Status: Queued
# StepRun( batch-scoring ) Status: Running
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
# 2020/11/27 17:57:22 Downloading source code...
# 2020/11/27 17:57:24 Finished downloading source code
# 2020/11/27 17:57:24 Creating Docker network: acb_default_network, driver: 'bridge'
# 2020/11/27 17:57:24 Successfully set up Docker network: acb_default_network
# 2020/11/27 17:57:24 Setting up Docker configuration...
# 2020/11/27 17:57:25 Successfully set up Docker configuration
# 2020/11/27 17:57:25 Logging in to registry: b4ebf977fa1b4412adb84bc5f3bef665.azurecr.io
# 2020/11/27 17:57:31 Successfully logged into b4ebf977fa1b4412adb84bc5f3bef665.azurecr.io
# 2020/11/27 17:57:31 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2020/11/27 17:57:31 Scanning for dependencies...
# 2020/11/27 17:57:32 Successfully scanned dependencies
# 2020/11/27 17:57:32 Launching container with name: acb_step_0
# Sending build context to Docker daemon     64kB
#
# Step 1/15 : FROM mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200821.v1@sha256:8cee6f674276dddb23068d2710da7f7f95b119412cc482675ac79ba45a4acf99
# sha256:8cee6f674276dddb23068d2710da7f7f95b119412cc482675ac79ba45a4acf99: Pulling from azureml/intelmpi2018.3-ubuntu16.04
# Digest: sha256:8cee6f674276dddb23068d2710da7f7f95b119412cc482675ac79ba45a4acf99
# Status: Downloaded newer image for mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200821.v1@sha256:8cee6f674276dddb23068d2710da7f7f95b119412cc482675ac79ba45a4acf99
#  ---> 287916b809d9
# Step 2/15 : USER root
#  ---> Running in 8b6a5ea0fd99
# Removing intermediate container 8b6a5ea0fd99
#  ---> 2a7444f200d4
# Step 3/15 : RUN mkdir -p $HOME/.cache
#  ---> Running in c91b6eabf0c4
# Removing intermediate container c91b6eabf0c4
#  ---> 50d2c8e9a4aa
# Step 4/15 : WORKDIR /
#  ---> Running in e220bbb548a7
# Removing intermediate container e220bbb548a7
#  ---> d6084db6498f
# Step 5/15 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> cb0d610a1789
# Step 6/15 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in d7234e15a1ab
# Removing intermediate container d7234e15a1ab
#  ---> 6236b42cb13a
# Step 7/15 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> 6d6eaeb6be60
# Step 8/15 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_da3e97fcb51801118b8e80207f3e01ad -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in 68b1bc8359c2
# Warning: you have pip-installed dependencies in your environment file, but you do not list pip itself as one of your conda dependencies.  Conda may not use the correct pip to install your packages, and they may end up in the wrong place.  Please add an explicit pip dependency.  I'm adding one for you, but still nagging you.
# Collecting package metadata (repodata.json): ...working...
# done
# Solving environment: ...working... done
#
# Downloading and Extracting Packages
#
# openssl-1.0.2u       | 3.1 MB    |            |   0%
# openssl-1.0.2u       | 3.1 MB    |            |   0%
# openssl-1.0.2u       | 3.1 MB    | #####1     |  51%
# openssl-1.0.2u       | 3.1 MB    | ########## | 100%
#
# tk-8.6.10            | 3.2 MB    |            |   0%
# tk-8.6.10            | 3.2 MB    | #########2 |  92%
# tk-8.6.10            | 3.2 MB    | ########## | 100%
#
# certifi-2020.6.20    | 160 KB    |            |   0%
# certifi-2020.6.20    | 160 KB    | ########## | 100%
#
# libgcc-ng-9.1.0      | 8.1 MB    |            |   0%
# libgcc-ng-9.1.0      | 8.1 MB    | ####9      |  50%
# libgcc-ng-9.1.0      | 8.1 MB    | ########## | 100%
#
# ncurses-6.0          | 907 KB    |            |   0%
# ncurses-6.0          | 907 KB    | ########## | 100%
#
# libffi-3.2.1         | 52 KB     |            |   0%
# libffi-3.2.1         | 52 KB     | ########## | 100%
#
# readline-7.0         | 387 KB    |            |   0%
# readline-7.0         | 387 KB    | ########## | 100%
#
# ca-certificates-2020 | 128 KB    |            |   0%
# ca-certificates-2020 | 128 KB    | ########## | 100%
#
# python-3.6.2         | 27.0 MB   |            |   0%
# python-3.6.2         | 27.0 MB   | ##         |  20%
# python-3.6.2         | 27.0 MB   | ######     |  60%
# python-3.6.2         | 27.0 MB   | ########## | 100%
#
# wheel-0.35.1         | 36 KB     |            |   0%
# wheel-0.35.1         | 36 KB     | ########## | 100%
#
# xz-5.2.5             | 438 KB    |            |   0%
# xz-5.2.5             | 438 KB    | ########## | 100%
#
# libstdcxx-ng-9.1.0   | 4.0 MB    |            |   0%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ########## | 100%
#
# setuptools-50.3.0    | 891 KB    |            |   0%
# setuptools-50.3.0    | 891 KB    | ########## | 100%
#
# sqlite-3.23.1        | 1.5 MB    |            |   0%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
#
# libedit-3.1          | 171 KB    |            |   0%
# libedit-3.1          | 171 KB    | ########## | 100%
#
# zlib-1.2.11          | 120 KB    |            |   0%
# zlib-1.2.11          | 120 KB    | ########## | 100%
#
# pip-20.2.4           | 2.0 MB    |            |   0%
# pip-20.2.4           | 2.0 MB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_da3e97fcb51801118b8e80207f3e01ad/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.wizxurvk.requirements.txt']
# Pip subprocess output:
# Collecting azureml-defaults
#   Downloading azureml_defaults-1.18.0-py3-none-any.whl (3.1 kB)
# Collecting applicationinsights>=0.11.7
#   Downloading applicationinsights-0.11.9-py2.py3-none-any.whl (58 kB)
# Collecting werkzeug<=1.0.1,>=0.16.1
#   Downloading Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
# Collecting gunicorn==19.9.0
#   Downloading gunicorn-19.9.0-py2.py3-none-any.whl (112 kB)
# Collecting azureml-core~=1.18.0
#   Downloading azureml_core-1.18.0.post4-py3-none-any.whl (2.1 MB)
# Collecting azureml-model-management-sdk==1.0.1b6.post1
#   Downloading azureml_model_management_sdk-1.0.1b6.post1-py2.py3-none-any.whl (130 kB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting flask==1.0.3
#   Downloading Flask-1.0.3-py2.py3-none-any.whl (92 kB)
# Collecting azureml-dataset-runtime[fuse]~=1.18.0
#   Downloading azureml_dataset_runtime-1.18.0-py3-none-any.whl (3.4 kB)
# Collecting pytz
#   Downloading pytz-2020.4-py2.py3-none-any.whl (509 kB)
# Collecting azure-mgmt-storage<16.0.0,>=1.5.0
#   Downloading azure_mgmt_storage-11.2.0-py2.py3-none-any.whl (547 kB)
# Collecting pathspec
#   Downloading pathspec-0.8.1-py2.py3-none-any.whl (28 kB)
# Collecting azure-mgmt-authorization<1.0.0,>=0.40.0
#   Downloading azure_mgmt_authorization-0.61.0-py2.py3-none-any.whl (94 kB)
# Collecting PyJWT<2.0.0
#   Downloading PyJWT-1.7.1-py2.py3-none-any.whl (18 kB)
# Collecting requests>=2.19.1
#   Downloading requests-2.25.0-py2.py3-none-any.whl (61 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*
#   Downloading cryptography-3.2.1-cp35-abi3-manylinux2010_x86_64.whl (2.6 MB)
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting docker
#   Downloading docker-4.4.0-py2.py3-none-any.whl (146 kB)
# Collecting msrestazure>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting msrest>=0.5.1
#   Downloading msrest-0.6.19-py2.py3-none-any.whl (84 kB)
# Collecting urllib3>=1.23
#   Downloading urllib3-1.26.2-py2.py3-none-any.whl (136 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting contextlib2
#   Downloading contextlib2-0.6.0.post1-py2.py3-none-any.whl (9.8 kB)
# Collecting python-dateutil>=2.7.3
#   Downloading python_dateutil-2.8.1-py2.py3-none-any.whl (227 kB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-2.8.0-py2.py3-none-any.whl (718 kB)
# Collecting ruamel.yaml>=0.15.35
#   Downloading ruamel.yaml-0.16.12-py2.py3-none-any.whl (111 kB)
# Collecting pyopenssl<20.0.0
#   Downloading pyOpenSSL-19.1.0-py2.py3-none-any.whl (53 kB)
# Collecting azure-mgmt-resource<15.0.0,>=1.2.1
#   Downloading azure_mgmt_resource-10.3.0-py2.py3-none-any.whl (1.0 MB)
# Collecting adal>=1.2.0
#   Downloading adal-1.2.5-py2.py3-none-any.whl (55 kB)
# Collecting SecretStorage
#   Downloading SecretStorage-3.3.0-py3-none-any.whl (14 kB)
# Collecting jmespath
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting ndg-httpsclient
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting azure-common>=1.1.12
#   Downloading azure_common-1.1.26-py2.py3-none-any.whl (12 kB)
# Collecting azure-mgmt-keyvault<7.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-2.2.0-py2.py3-none-any.whl (89 kB)
# Collecting jsonpickle
#   Downloading jsonpickle-1.4.1-py2.py3-none-any.whl (36 kB)
# Collecting six>=1.10
#   Downloading six-1.15.0-py2.py3-none-any.whl (10 kB)
# Collecting liac-arff>=2.1.1
#   Downloading liac-arff-2.5.0.tar.gz (13 kB)
# Collecting numpy>=1.13.0
#   Downloading numpy-1.19.4-cp36-cp36m-manylinux2010_x86_64.whl (14.5 MB)
# Collecting pandas>=0.20.2
#   Downloading pandas-1.1.4-cp36-cp36m-manylinux1_x86_64.whl (9.5 MB)
# Collecting dill>=0.2.7.1
#   Downloading dill-0.3.3-py2.py3-none-any.whl (81 kB)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting click>=5.1
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
# Collecting Jinja2>=2.10
#   Downloading Jinja2-2.11.2-py2.py3-none-any.whl (125 kB)
# Collecting pyarrow<2.0.0,>=0.17.0
#   Downloading pyarrow-1.0.1-cp36-cp36m-manylinux2014_x86_64.whl (17.3 MB)
# Collecting azureml-dataprep<2.5.0a,>=2.4.0a
#   Downloading azureml_dataprep-2.4.4-py3-none-any.whl (28.2 MB)
# Collecting fusepy<4.0.0,>=3.0.1; extra == "fuse"
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /azureml-envs/azureml_da3e97fcb51801118b8e80207f3e01ad/lib/python3.6/site-packages (from requests>=2.19.1->azureml-core~=1.18.0->azureml-defaults->-r /azureml-environment-setup/condaenv.wizxurvk.requirements.txt (line 1)) (2020.6.20)
# Collecting chardet<4,>=3.0.2
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# Collecting idna<3,>=2.5
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
# Collecting cffi!=1.11.3,>=1.8
#   Downloading cffi-1.14.4-cp36-cp36m-manylinux1_x86_64.whl (401 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-0.57.0-py2.py3-none-any.whl (200 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.9"
#   Downloading ruamel.yaml.clib-0.2.2-cp36-cp36m-manylinux1_x86_64.whl (549 kB)
# Collecting jeepney>=0.6
#   Downloading jeepney-0.6.0-py3-none-any.whl (45 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting importlib-metadata
#   Downloading importlib_metadata-3.1.0-py2.py3-none-any.whl (9.3 kB)
# Collecting MarkupSafe>=0.23
#   Downloading MarkupSafe-1.1.1-cp36-cp36m-manylinux1_x86_64.whl (27 kB)
# Collecting azureml-dataprep-rslex<1.3.0a,>=1.2.0dev0
#   Downloading azureml_dataprep_rslex-1.2.3-cp36-cp36m-manylinux2010_x86_64.whl (7.9 MB)
# Collecting cloudpickle<2.0.0,>=1.1.0
#   Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Collecting dotnetcore2<3.0.0,>=2.1.14
#   Downloading dotnetcore2-2.1.19-py3-none-manylinux1_x86_64.whl (28.7 MB)
# Collecting azureml-dataprep-native<25.0.0,>=24.0.0
#   Downloading azureml_dataprep_native-24.0.0-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting azure-identity<1.5.0,>=1.2.0
#   Downloading azure_identity-1.4.1-py2.py3-none-any.whl (86 kB)
# Collecting pycparser
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.4.0-py3-none-any.whl (5.2 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.5.0-py2.py3-none-any.whl (18 kB)
# Collecting azure-core<2.0.0,>=1.0.0
#   Downloading azure_core-1.9.0-py2.py3-none-any.whl (124 kB)
# Collecting msal<2.0.0,>=1.3.0
#   Downloading msal-1.6.0-py2.py3-none-any.whl (50 kB)
# Collecting msal-extensions~=0.2.2
#   Downloading msal_extensions-0.2.2-py2.py3-none-any.whl (15 kB)
# Collecting portalocker~=1.0; platform_system != "Windows"
#   Downloading portalocker-1.7.1-py2.py3-none-any.whl (10 kB)
# Building wheels for collected packages: json-logging-py, liac-arff, fusepy
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3924 sha256=6de0163f4b1783b546e61b5e72b6a75831e5d48d0c06eb8f42c3ed5e61f6b2a3
#   Stored in directory: /root/.cache/pip/wheels/e2/1d/52/535a274b9c2ce7d4064838f2bdb62013801281ef7d7f21e2ee
#   Building wheel for liac-arff (setup.py): started
#   Building wheel for liac-arff (setup.py): finished with status 'done'
#   Created wheel for liac-arff: filename=liac_arff-2.5.0-py3-none-any.whl size=11730 sha256=37a0f9c0b783f208bad77a01aaae27d56a8961df9f3dd77967c54ef2a46c8d44
#   Stored in directory: /root/.cache/pip/wheels/53/ba/da/8562a6a6dbb428fd1ecc21053106df3948645cd991958f669b
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10504 sha256=565acad61902f472e1aad10bfa91a8dbee579c3780bf6a3ef88b1d7f70dae5cf
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
# Successfully built json-logging-py liac-arff fusepy
# Installing collected packages: applicationinsights, werkzeug, gunicorn, pytz, azure-common, six, isodate, oauthlib, chardet, idna, urllib3, requests, requests-oauthlib, msrest, PyJWT, python-dateutil, pycparser, cffi, cryptography, adal, msrestazure, azure-mgmt-storage, pathspec, azure-mgmt-authorization, azure-graphrbac, websocket-client, docker, backports.weakref, backports.tempfile, contextlib2, azure-mgmt-containerregistry, ruamel.yaml.clib, ruamel.yaml, pyopenssl, azure-mgmt-resource, jeepney, SecretStorage, jmespath, pyasn1, ndg-httpsclient, azure-mgmt-keyvault, zipp, importlib-metadata, jsonpickle, azureml-core, liac-arff, numpy, pandas, dill, azureml-model-management-sdk, json-logging-py, configparser, itsdangerous, click, MarkupSafe, Jinja2, flask, pyarrow, azureml-dataprep-rslex, cloudpickle, distro, dotnetcore2, azureml-dataprep-native, azure-core, msal, portalocker, msal-extensions, azure-identity, azureml-dataprep, fusepy, azureml-dataset-runtime, azureml-defaults
# Successfully installed Jinja2-2.11.2 MarkupSafe-1.1.1 PyJWT-1.7.1 SecretStorage-3.3.0 adal-1.2.5 applicationinsights-0.11.9 azure-common-1.1.26 azure-core-1.9.0 azure-graphrbac-0.61.1 azure-identity-1.4.1 azure-mgmt-authorization-0.61.0 azure-mgmt-containerregistry-2.8.0 azure-mgmt-keyvault-2.2.0 azure-mgmt-resource-10.3.0 azure-mgmt-storage-11.2.0 azureml-core-1.18.0.post4 azureml-dataprep-2.4.4 azureml-dataprep-native-24.0.0 azureml-dataprep-rslex-1.2.3 azureml-dataset-runtime-1.18.0 azureml-defaults-1.18.0 azureml-model-management-sdk-1.0.1b6.post1 backports.tempfile-1.0 backports.weakref-1.0.post1 cffi-1.14.4 chardet-3.0.4 click-7.1.2 cloudpickle-1.6.0 configparser-3.7.4 contextlib2-0.6.0.post1 cryptography-3.2.1 dill-0.3.3 distro-1.5.0 docker-4.4.0 dotnetcore2-2.1.19 flask-1.0.3 fusepy-3.0.1 gunicorn-19.9.0 idna-2.10 importlib-metadata-3.1.0 isodate-0.6.0 itsdangerous-1.1.0 jeepney-0.6.0 jmespath-0.10.0 json-logging-py-0.2 jsonpickle-1.4.1 liac-arff-2.5.0 msal-1.6.0 msal-extensions-0.2.2 msrest-0.6.19 msrestazure-0.6.4 ndg-httpsclient-0.5.1 numpy-1.19.4 oauthlib-3.1.0 pandas-1.1.4 pathspec-0.8.1 portalocker-1.7.1 pyarrow-1.0.1 pyasn1-0.4.8 pycparser-2.20 pyopenssl-19.1.0 python-dateutil-2.8.1 pytz-2020.4 requests-2.25.0 requests-oauthlib-1.3.0 ruamel.yaml-0.16.12 ruamel.yaml.clib-0.2.2 six-1.15.0 urllib3-1.26.2 websocket-client-0.57.0 werkzeug-1.0.1 zipp-3.4.0
#
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_da3e97fcb51801118b8e80207f3e01ad
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.7.12
#   latest version: 4.9.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# WARNING: /root/.conda/pkgs does not exist
# Removing intermediate container 68b1bc8359c2
#  ---> 9316a5e8dacc
# Step 9/15 : ENV PATH /azureml-envs/azureml_da3e97fcb51801118b8e80207f3e01ad/bin:$PATH
#  ---> Running in 267d78f89be7
# Removing intermediate container 267d78f89be7
#  ---> 6bfaa4dbbb65
# Step 10/15 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_da3e97fcb51801118b8e80207f3e01ad
#  ---> Running in cdb7ca188166
# Removing intermediate container cdb7ca188166
#  ---> 30affcf5dddd
# Step 11/15 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_da3e97fcb51801118b8e80207f3e01ad/lib:$LD_LIBRARY_PATH
#  ---> Running in f23b36ecd937
# Removing intermediate container f23b36ecd937
#  ---> cdb3813810f1
# Step 12/15 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> b09303396682
# Step 13/15 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in 8655ac8fe459
# Removing intermediate container 8655ac8fe459
#  ---> 8cba7b2c6b40
# Step 14/15 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in 6bd75506f619
# Removing intermediate container 6bd75506f619
#  ---> f5fe37de31a6
# Step 15/15 : CMD ["bash"]
#  ---> Running in b391e7a6c6b0
# Removing intermediate container b391e7a6c6b0
#  ---> f2568f05a6c3
# Successfully built f2568f05a6c3
# Successfully tagged b4ebf977fa1b4412adb84bc5f3bef665.azurecr.io/azureml/azureml_1a31af1e7a24bf75a2aeeda4db33c10b:latest
# 2020/11/27 17:59:37 Successfully executed container: acb_step_0
# 2020/11/27 17:59:37 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2020/11/27 17:59:37 Pushing image: b4ebf977fa1b4412adb84bc5f3bef665.azurecr.io/azureml/azureml_1a31af1e7a24bf75a2aeeda4db33c10b:latest, attempt 1
# The push refers to repository [b4ebf977fa1b4412adb84bc5f3bef665.azurecr.io/azureml/azureml_1a31af1e7a24bf75a2aeeda4db33c10b]
# 601798c67707: Preparing
# 2177e799c017: Preparing
# aed9fc5f9bb5: Preparing
# 12bb0030354c: Preparing
# 935fc78c170e: Preparing
# 44a30f3ca912: Preparing
# 13e378616f24: Preparing
# efc99d952c3d: Preparing
# 9e292a80b88a: Preparing
# 5e1805eb9eb5: Preparing
# 8dab94e6d05c: Preparing
# 2817caf0a082: Preparing
# aece08fd27fc: Preparing
# 4caea5ef1f0b: Preparing
# dcc0cc99372e: Preparing
# 87c128261339: Preparing
# 41a253a417e6: Preparing
# e06660e80cf4: Preparing
# 5e1805eb9eb5: Waiting
# 8dab94e6d05c: Waiting
# 2817caf0a082: Waiting
# aece08fd27fc: Waiting
# 4caea5ef1f0b: Waiting
# dcc0cc99372e: Waiting
# 87c128261339: Waiting
# 41a253a417e6: Waiting
# e06660e80cf4: Waiting
# 44a30f3ca912: Waiting
# 13e378616f24: Waiting
# efc99d952c3d: Waiting
# 9e292a80b88a: Waiting
# aed9fc5f9bb5: Pushed
# 601798c67707: Pushed
# 12bb0030354c: Pushed
# 935fc78c170e: Pushed
# 44a30f3ca912: Pushed
# efc99d952c3d: Pushed
# 13e378616f24: Pushed
# 9e292a80b88a: Pushed
#
# aece08fd27fc: Pushed
# 8dab94e6d05c: Pushed
# 2817caf0a082: Pushed
# dcc0cc99372e: Pushed
# 87c128261339: Pushed
# 41a253a417e6: Pushed
# 5e1805eb9eb5: Pushed
# 4caea5ef1f0b: Pushed
# e06660e80cf4: Pushed
# 2177e799c017: Pushed
# latest: digest: sha256:b2924c4ca8b54e6cc5e977eca55837b432e95bdbf7789f990476e7b962e5763c size: 4095
# 2020/11/27 18:01:03 Successfully pushed image: b4ebf977fa1b4412adb84bc5f3bef665.azurecr.io/azureml/azureml_1a31af1e7a24bf75a2aeeda4db33c10b:latest
# 2020/11/27 18:01:03 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 126.136992)
# 2020/11/27 18:01:03 Populating digests for step ID: acb_step_0...
# 2020/11/27 18:01:05 Successfully populated digests for step ID: acb_step_0
# 2020/11/27 18:01:05 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 85.809185)
# 2020/11/27 18:01:05 The following dependencies were found:
# 2020/11/27 18:01:05
# - image:
#     registry: b4ebf977fa1b4412adb84bc5f3bef665.azurecr.io
#     repository: azureml/azureml_1a31af1e7a24bf75a2aeeda4db33c10b
#     tag: latest
#     digest: sha256:b2924c4ca8b54e6cc5e977eca55837b432e95bdbf7789f990476e7b962e5763c
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/intelmpi2018.3-ubuntu16.04
#     tag: 20200821.v1
#     digest: sha256:8cee6f674276dddb23068d2710da7f7f95b119412cc482675ac79ba45a4acf99
#   git: {}
#
# Run ID: cd3 was successful after 3m44s
#
# Streaming azureml-logs/55_azureml-execution-tvmps_f5757fa91c0bd5624b936792a9043f2f3afc65992a333f7c45bfbcf20aea7dfd_d.txt
# ========================================================================================================================
# 2020-11-27T18:01:39Z Starting output-watcher...
# 2020-11-27T18:01:39Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2020-11-27T18:01:40Z Executing 'Copy ACR Details file' on 10.0.0.8
# 2020-11-27T18:01:40Z Copy ACR Details file succeeded on 10.0.0.8. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_1a31af1e7a24bf75a2aeeda4db33c10b
# 8e097b52bfb8: Already exists
# a613a9b4553c: Already exists
# acc000f01536: Already exists
# 73eef93b7466: Already exists
# d5a54c1fb97f: Already exists
# 1536f6ca931b: Already exists
# d7b631d130cb: Already exists
# 75ffe8dfb222: Already exists
# 86b4bf2f8d5f: Already exists
# 5335952fa8d3: Already exists
# 96fa3cc6fe10: Already exists
# e428dd9daa94: Already exists
# 86d53f127672: Pulling fs layer
# e648e681e222: Pulling fs layer
# 033f58ad282c: Pulling fs layer
# c88ecbb55b3b: Pulling fs layer
# f1ca22fb91b5: Pulling fs layer
# 8f339ebdc176: Pulling fs layer
# c88ecbb55b3b: Waiting
# f1ca22fb91b5: Waiting
# 8f339ebdc176: Waiting
# e648e681e222: Verifying Checksum
# e648e681e222: Download complete
# 86d53f127672: Download complete
# c88ecbb55b3b: Download complete
# 86d53f127672: Pull complete
# 8f339ebdc176: Download complete
# 033f58ad282c: Download complete
# e648e681e222: Pull complete
# 033f58ad282c: Pull complete
# c88ecbb55b3b: Pull complete
# f1ca22fb91b5: Verifying Checksum
# f1ca22fb91b5: Download complete
# f1ca22fb91b5: Pull complete
# 8f339ebdc176: Pull complete
# Digest: sha256:b2924c4ca8b54e6cc5e977eca55837b432e95bdbf7789f990476e7b962e5763c
# Status: Downloaded newer image for b4ebf977fa1b4412adb84bc5f3bef665.azurecr.io/azureml/azureml_1a31af1e7a24bf75a2aeeda4db33c10b:latest
# b4ebf977fa1b4412adb84bc5f3bef665.azurecr.io/azureml/azureml_1a31af1e7a24bf75a2aeeda4db33c10b:latest
# 2020-11-27T18:02:10Z Check if container a0e18dd2-c478-419a-965b-a918d577f270 already exist exited with 0,
#
# b3d04d87582b3ef0cda241a2d241c0217f13aec37eca1998f0623a5f0bb31b29
# 2020/11/27 18:02:17 Starting App Insight Logger for task:  containerSetup
# 2020/11/27 18:02:17 Version: 3.0.01417.0012 Branch: 56 Commit: d244ddd
# 2020/11/27 18:02:17 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2020/11/27 18:02:17 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2020/11/27 18:02:17 sshd inside container not required for job, skipping setup.
# 2020/11/27 18:02:17 All App Insights Logs was send successfully
# 2020-11-27T18:02:17Z Starting docker container succeeded.
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
# 2020/11/27 18:02:32 Attempt 1 of http call to http://10.0.0.8:16384/sendlogstoartifacts/info
# 2020/11/27 18:02:32 Attempt 1 of http call to http://10.0.0.8:16384/sendlogstoartifacts/status
# [2020-11-27T18:02:34.241385] Entering context manager injector.
# [context_manager_injector.py] Command line Options: Namespace(inject=['ProjectPythonPath:context_managers.ProjectPythonPath', 'RunHistory:context_managers.RunHistory', 'TrackUserError:context_managers.TrackUserError'], invocation=['driver/amlbi_main.py', '--client_sdk_version', '1.18.0', '--scoring_module_name', 'batch_inference.py', '--mini_batch_size', '1048576', '--error_threshold', '5', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--append_row_file_name', 'batch_inference.txt', '--output', '/mnt/batch/tasks/shared/LS_root/jobs/quick-starts-ws-128108/azureml/a0e18dd2-c478-419a-965b-a918d577f270/mounts/workspaceblobstore/azureml/a0e18dd2-c478-419a-965b-a918d577f270/scores', '--model_name', 'deployments-bankmarketing', '--input_ds_0', 'examples_batch'])
# Script type = None
# Starting the daemon thread to refresh tokens in background for process with pid = 111
# Entering Run History Context Manager.
# Current directory:  /mnt/batch/tasks/shared/LS_root/jobs/quick-starts-ws-128108/azureml/a0e18dd2-c478-419a-965b-a918d577f270/mounts/workspaceblobstore/azureml/a0e18dd2-c478-419a-965b-a918d577f270
# Preparing to call script [ driver/amlbi_main.py ] with arguments: ['--client_sdk_version', '1.18.0', '--scoring_module_name', 'batch_inference.py', '--mini_batch_size', '1048576', '--error_threshold', '5', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--append_row_file_name', 'batch_inference.txt', '--output', '/mnt/batch/tasks/shared/LS_root/jobs/quick-starts-ws-128108/azureml/a0e18dd2-c478-419a-965b-a918d577f270/mounts/workspaceblobstore/azureml/a0e18dd2-c478-419a-965b-a918d577f270/scores', '--model_name', 'deployments-bankmarketing', '--input_ds_0', 'examples_batch']
# After variable expansion, calling script [ driver/amlbi_main.py ] with arguments: ['--client_sdk_version', '1.18.0', '--scoring_module_name', 'batch_inference.py', '--mini_batch_size', '1048576', '--error_threshold', '5', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--append_row_file_name', 'batch_inference.txt', '--output', '/mnt/batch/tasks/shared/LS_root/jobs/quick-starts-ws-128108/azureml/a0e18dd2-c478-419a-965b-a918d577f270/mounts/workspaceblobstore/azureml/a0e18dd2-c478-419a-965b-a918d577f270/scores', '--model_name', 'deployments-bankmarketing', '--input_ds_0', 'examples_batch']
#
# Starting the daemon thread to refresh tokens in background for process with pid = 111
#
#
# [2020-11-27T18:07:56.810832] The experiment failed. Finalizing run...
# Cleaning up all outstanding Run operations, waiting 900.0 seconds
# 2 items cleaning up...
# Cleanup took 0.15024900436401367 seconds
# Traceback (most recent call last):
#   File "driver/amlbi_main.py", line 94, in <module>
#     main()
#   File "driver/amlbi_main.py", line 87, in main
#     booter.start()
#   File "driver/azureml_user/parallel_run/boot.py", line 295, in start
#     self.start_sys_main()
#   File "driver/azureml_user/parallel_run/boot.py", line 207, in start_sys_main
#     self.run(cmd)
#   File "driver/azureml_user/parallel_run/boot.py", line 162, in run
#     BootResult().check_result(stdout)
#   File "driver/azureml_user/parallel_run/boot_result.py", line 32, in check_result
#     stacktrace="",  # Set to empty since it contained in message
# azureml_common.parallel_run.exception.EntryScriptException: Entry script error. No progress update in 270 seconds. Updated: False, total wait from last update: 275 seconds, remaining -5 seconds. 0/1 items processed. new_finished_tasks: 0.
# No mini batch has been processed.
# The init() function in the entry script had raised exception for 228 times. Please check logs at logs/user/error/* for details.
#   * Error '2. usage: main.py [-h] --model_name MODEL_NAME
# main.py: error: unrecognized arguments: --client_sdk_version 1.18.0 --scoring_module_name batch_inference.py --mini_batch_size 1048576 --error_threshold 5 --output_action append_row --logging_level INFO --run_invocation_timeout 60 --run_max_try 3 --create_snapshot_at_runtime True --append_row_file_name batch_inference.txt --output /mnt/batch/tasks/shared/LS_root/jobs/quick-starts-ws-128108/azureml/a0e18dd2-c478-419a-965b-a918d577f270/mounts/workspaceblobstore/azureml/a0e18dd2-c478-419a-965b-a918d577f270/scores --input_ds_0 examples_batch --aml_core_version 1.18.0.post4 --dataprep_version 2.4.4 --bf89b5b0_523f_4782_aedc_61bd625ee81a {"working_dir": "/mnt/batch/tasks/shared/LS_root/jobs/quick-starts-ws-128108/azureml/a0e18dd2-c478-419a-965b-a918d577f270/mounts/workspaceblobstore/azureml/a0e18dd2-c478-419a-965b-a918d577f270", "temp_dir": "/mnt/batch/tasks/shared/LS_root/jobs/quick-starts-ws-128108/azureml/a0e18dd2-c478-419a-965b-a918d577f270/wd/azureml-bi/151", "port": 37555, "using_file_dataset": false, "using_tabular_dataset": true, "agent_name": "process000", "gpu_index": -1, "mini_batch_size": 1048576}.' occurred 1 times.
#   * Error '2. usage: main.py [-h] --model_name MODEL_NAME
# main.py: error: unrecognized arguments: --client_sdk_version 1.18.0 --scoring_module_name batch_inference.py --mini_batch_size 1048576 --error_threshold 5 --output_action append_row --logging_level INFO --run_invocation_timeout 60 --run_max_try 3 --create_snapshot_at_runtime True --append_row_file_name batch_inference.txt --output /mnt/batch/tasks/shared/LS_root/jobs/quick-starts-ws-128108/azureml/a0e18dd2-c478-419a-965b-a918d577f270/mounts/workspaceblobstore/azureml/a0e18dd2-c478-419a-965b-a918d577f270/scores --input_ds_0 examples_batch --aml_core_version 1.18.0.post4 --dataprep_version 2.4.4 --bf89b5b0_523f_4782_aedc_61bd625ee81a {"working_dir": "/mnt/batch/tasks/shared/LS_root/jobs/quick-starts-ws-128108/azureml/a0e18dd2-c478-419a-965b-a918d577f270/mounts/workspaceblobstore/azureml/a0e18dd2-c478-419a-965b-a918d577f270", "temp_dir": "/mnt/batch/tasks/shared/LS_root/jobs/quick-starts-ws-128108/azureml/a0e18dd2-c478-419a-965b-a918d577f270/wd/azureml-bi/151", "port": 37555, "using_file_dataset": false, "using_tabular_dataset": true, "agent_name": "process001", "gpu_index": -1, "mini_batch_size": 1048576}.' occurred 1 times.
#   * Error '2. usage: main.py [-h] --model_name MODEL_NAME
# main.py: error: unrecognized arguments: --client_sdk_version 1.18.0 --scoring_module_name batch_inference.py --mini_batch_size 1048576 --error_threshold 5 --output_action append_row --logging_level INFO --run_invocation_timeout 60 --run_max_try 3 --create_snapshot_at_runtime True --append_row_file_name batch_inference.txt --output /mnt/batch/tasks/shared/LS_root/jobs/quick-starts-ws-128108/azureml/a0e18dd2-c478-419a-965b-a918d577f270/mounts/workspaceblobstore/azureml/a0e18dd2-c478-419a-965b-a918d577f270/scores --input_ds_0 examples_batch --aml_core_version 1.18.0.post4 --dataprep_version 2.4.4 --bf89b5b0_523f_4782_aedc_61bd625ee81a {"working_dir": "/mnt/batch/tasks/shared/LS_root/jobs/quick-starts-ws-128108/azureml/a0e18dd2-c478-419a-965b-a918d577f270/mounts/workspaceblobstore/azureml/a0e18dd2-c478-419a-965b-a918d577f270", "temp_dir": "/mnt/batch/tasks/shared/LS_root/jobs/quick-starts-ws-128108/azureml/a0e18dd2-c478-419a-965b-a918d577f270/wd/azureml-bi/151", "port": 37555, "using_file_dataset": false, "using_tabular_dataset": true, "agent_name": "process002", "gpu_index": -1, "mini_batch_size": 1048576}.' occurred 1 times.
#   * Error '2. usage: main.py [-h] --model_name MODEL_NAME
# main.py: error: unrecogn.
#
# [2020-11-27T18:07:57.160963] Finished context manager injector with Exception.
# 2020/11/27 18:07:59 Failed to run the wrapper cmd with err: exit status 1
# 2020/11/27 18:07:59 Attempt 1 of http call to http://10.0.0.8:16384/sendlogstoartifacts/status
# 2020/11/27 18:07:59 mpirun version string: {
# Intel(R) MPI Library for Linux* OS, Version 2018 Update 3 Build 20180411 (id: 18329)
# Copyright 2003-2018 Intel Corporation.
# }
# 2020/11/27 18:07:59 MPI publisher: intel ; version: 2018
# 2020/11/27 18:07:59 Process Exiting with Code:  1
#
# Streaming azureml-logs/75_job_post-tvmps_f5757fa91c0bd5624b936792a9043f2f3afc65992a333f7c45bfbcf20aea7dfd_d.txt
# ===============================================================================================================
# [2020-11-27T18:08:00.516265] Entering job release
# [2020-11-27T18:08:01.451411] Starting job release
# [2020-11-27T18:08:01.452059] Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 5685
# [2020-11-27T18:08:01.454367] job release stage : upload_datastore starting...
# [2020-11-27T18:08:01.460008] job release stage : start importing azureml.history._tracking in run_history_release.
# [2020-11-27T18:08:01.460207] job release stage : copy_batchai_cached_logs starting...
# [2020-11-27T18:08:01.460249] job release stage : copy_batchai_cached_logs completed...
# [2020-11-27T18:08:01.460346] job release stage : execute_job_release starting...
# [2020-11-27T18:08:01.460765] Entering context manager injector.
# [2020-11-27T18:08:01.683169] job release stage : upload_datastore completed...
# [2020-11-27T18:08:01.711946] job release stage : send_run_telemetry starting...
# [2020-11-27T18:08:01.855077] job release stage : execute_job_release completed...
# [2020-11-27T18:08:03.049287] job release stage : send_run_telemetry completed...
# [2020-11-27T18:08:03.049478] Job release is complete
#
# StepRun(batch-scoring) Execution Summary
# =========================================
# StepRun( batch-scoring ) Status: Failed
# ---------------------------------------------------------------------------
# ActivityFailedException                   Traceback (most recent call last)
# <ipython-input-29-8f266af35dcc> in <module>
#       2 pipeline = Pipeline(workspace=ws, steps=[batch_score_step])
#       3 batch_run = experiment.submit(pipeline)
# ----> 4 batch_run.wait_for_completion(show_output=True)
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/pipeline/core/run.py in wait_for_completion(self, show_output, timeout_seconds, raise_on_error)
#     293                             try:
#     294                                 step_run.wait_for_completion(timeout_seconds=timeout_seconds - time_elapsed,
# --> 295                                                              raise_on_error=raise_on_error)
#     296                             except TypeError as e:
#     297                                 # If there are package conflicts in the user's environment, the run rehydration
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/pipeline/core/run.py in wait_for_completion(self, show_output, timeout_seconds, raise_on_error)
#     735             try:
#     736                 return self._stream_run_output(timeout_seconds=timeout_seconds,
# --> 737                                                raise_on_error=raise_on_error)
#     738             except KeyboardInterrupt:
#     739                 error_message = "The output streaming for the run interrupted.\n" \
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/pipeline/core/run.py in _stream_run_output(self, timeout_seconds, raise_on_error)
#     823             print(json.dumps(error, indent=4))
#     824         if error and raise_on_error:
# --> 825             raise ActivityFailedException(error_details=json.dumps(error, indent=4))
#     826
#     827         print(final_details)
#
# ActivityFailedException: ActivityFailedException:
# 	Message: Activity Failed:
# {
#     "error": {
#         "code": "UserError",
#         "message": "AzureMLCompute job failed.\nJobFailed: Submitted script failed with a non-zero exit code; see the driver log file for details.",
#         "details": []
#     },
#     "correlation": {
#         "operation": null,
#         "request": "0946ed7ec48ee0f9"
#     },
#     "environment": "southcentralus",
#     "location": "southcentralus",
#     "time": "2020-11-27T18:08:12.215898Z",
#     "componentName": "execution-worker"
# }
# 	InnerException None
# 	ErrorResponse
# {
#     "error": {
#         "message": "Activity Failed:\n{\n    \"error\": {\n        \"code\": \"UserError\",\n        \"message\": \"AzureMLCompute job failed.\\nJobFailed: Submitted script failed with a non-zero exit code; see the driver log file for details.\",\n        \"details\": []\n    },\n    \"correlation\": {\n        \"operation\": null,\n        \"request\": \"0946ed7ec48ee0f9\"\n    },\n    \"environment\": \"southcentralus\",\n    \"location\": \"southcentralus\",\n    \"time\": \"2020-11-27T18:08:12.215898Z\",\n    \"componentName\": \"execution-worker\"\n}"
#     }
# }

# %%
# Publish pipeline
published_pipeline = batch_run.publish_pipeline(name="batch-scoring", description="Batch scoring for project 2", version=1.0)

# %%
# Interactive authentication to get authentication header
from azureml.pipeline.core.run import PipelineRun
from azureml.core.authentication import InteractiveLoginAuthentication
import requests

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()

# %% [markdown]
# ### ENDPOINT FOR THE PIPELINE

# %%
# Publish the pipeline to an endpoint
rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, headers=auth_header, json={"ExperimentName": "batch-scoring"})
run_id = response.json()["Id"]

# %%
# Run it again
published_pipeline_run = PipelineRun(ws.experiments["batch-scoring"], run_id)
RunDetails(published_pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …

# %% [markdown]
# ## Explore results

# %%
'''
results = next(pipeline_run.get_children())
batch_output = results.get_output_data("scores")        ## esta linea puede traer problemas
batch_output.download(local_path='./outputs')           ## esta linea puede traer problemas

for root, dirs, files in os.walk('./outputs'):
    for file in files:
        if file.endswith("batch_inference.txt"):
            result_file = os.path.join(root, file)
 '''

# %%
'''
df = pd.read_csv(result_file, header=None)    # delimiter=":"
df.columns = ["age","campaign","cons.conf.idx","cons.price.idx","contact","day_of_week","default","duration","education","emp.var.rate",
              "euribor3m","housing","job","loan","marital","month","nr.employed","pdays","poutcome","previous","prediction"]
df.head(10)
'''
